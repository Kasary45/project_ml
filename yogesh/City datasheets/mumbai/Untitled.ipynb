# %%
import numpy as np
import pandas as pd

# %%
mumbai=pd.read_csv('mumbai.csv')

# %%
pune=pd.read_csv('pune.csv')

# %%
city=pd.concat([mumbai,pune],ignore_index=True)

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
movies['lead actor']=movies['actors'].str.split('|').apply(lambda x:x[0])

# %%
city['Address'].str.split(',').apply[lambda x:x[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 city['Address'].str().split(',').apply[lambda x:x[0]]
#
# TypeError: 'StringMethods' object is not callable

# %%
movies[(movies['genres'].str.split('|').apply(lambda x:'Action'in x))

# %%
city['City']=city['Address'].str.split(',').apply(lambda x:x[0])

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
city.drop(columns=['main_city','City'],inplace=True)

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
city['City']=city['Address'].str.split(',').apply(lambda x:x[1])

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
city['locality']=city['Address'].str.split(',').apply(lambda x:x[0])

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
city.drop(columns=['Address'],inplace=True)

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
city.sample(15)
# Out:
#                            broker_consultancy    Rent  Builtup Area  \
# 16287              MY HOMES GATEWAY\nAGENT\n0   36000          1560
# 15049                           Seller\nOWNER  73,000          1400
# 17947              MY HOMES GATEWAY\nAGENT\n0   36000          1560
# 18108               Sai Real Estate\nAGENT\n0   41000          1250
# 17262                  Seller\nVERIFIED OWNER   15500           975
# 456                  Hari Om Estate\nAGENT\n-  96,000          1600
# 10421           Citizone Properties\nAGENT\n-  26,000           971
# 10568                 Prema Housing\nAGENT\n-  45,000           959
# 5249              Avenue Properties\nAGENT\n-  58,000          1600
# 19584                   NISHA SINGH\nAGENT\n0   51000          2500
# 10821  Sai Kripa Real Estate Agency\nAGENT\n-  50,000          1211
# 7734                 SSC Consultant\nAGENT\n-  1.85 L          1600
# 13807             Property Solution\nAGENT\n-  30,000          1400
# ...

# %%
city['Bathrooms']=city['Bathrooms'].str.split(' ').apply(lambda x:float(x[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 city['Bathrooms']=city['Bathrooms'].str.split(' ').apply(lambda x:float(x[0]))
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# ...

# %%
city['Bathrooms'] = city['Bathrooms'].str.split(' ').apply(lambda x: float(x[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 city['Bathrooms'] = city['Bathrooms'].str.split(' ').apply(lambda x: float(x[0]))
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# ...

# %%
def extract_first_number(x):
    if isinstance(x, str):
        # Split the string and convert the first part to float
        return float(x.split(' ')[0])
    elif isinstance(x, float):
        # If it's already a float, return it as is
        return x
    else:
        # Handle other cases (if any) or return NaN
        return float('nan')

city['Bathrooms'] = city['Bathrooms'].apply(extract_first_number)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 12
#       8     else:
#       9         # Handle other cases (if any) or return NaN
#      10         return float('nan')
# ---> 12 city['Bathrooms'] = city['Bathrooms'].apply(extract_first_number)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
# ...

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
city.shape[0]
# Out:
# 22896

# %%
for i in range (len(city['Deposit'])):
    if city['Deposit'][i]=="No Deposit":
        city['Deposit'][i]=0
    elif 'L'in city['Deposit'][i]:
        city['Deposit'][i].str.split('L').apply(lambda x:(x[0]*100000))
        
    else:
        city['Deposit'][i]=0

        

def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str) and 'L' in deposit:
        # Split on 'L', take the first part, convert to float, and multiply by 100000
        return float(deposit.split('L')[0]) * 100000
    else:
        # Handle other cases as needed
        return deposit

city['Deposit'] = city['Deposit'].apply(convert_deposit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       2 if city['Deposit'][i]=="No Deposit":
#       3     city['Deposit'][i]=0
# ----> 4 elif 'L'in city['Deposit'][i]:
#       5     city['Deposit'][i].str.split('L').apply(lambda x:(x[0]*100000))
#       7 else:
#
# TypeError: argument of type 'int' is not iterable

# %%
city['Bathrooms'] = city['Bathrooms'].str.split(' ').apply(lambda x: float(x[0]))

# %%
def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str) and 'L' in deposit:
        # Split on 'L', take the first part, convert to float, and multiply by 100000
        return float(deposit.split('L')[0]) * 100000
    else:
        # Handle other cases as needed
        return deposit

city['Deposit'] = city['Deposit'].apply(convert_deposit)

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 22891   Melange Consultancy\nAGENT\n-   48000          1300                2
# 22892           A Realities\nAGENT\n-   23000          1000                2
# 22893           KDH REALITY\nAGENT\n-   24000          1250                2
# 22894             FS Realty\nAGENT\n-   26000           950                2
# 22895       Envision Realty\nAGENT\n-   37000          1100                3
#
# ...

# %%
city.sample(50)
# Out:
#                            broker_consultancy    Rent  Builtup Area  \
# 17254                     FS Realty\nAGENT\n0   26000           950
# 21477                  Seller\nVERIFIED OWNER   12000           906
# 9140           Anjali Estate Agency\nAGENT\n-  60,000          1200
# 14869                           Seller\nOWNER  2.75 L          2250
# 3010    Shree Aniruddha Real Estate\nAGENT\n-  37,000          1000
# 10242                        Jugyah\nAGENT\n-  10,473           300
# 20027              MY HOMES GATEWAY\nAGENT\n0   36000          1560
# 2160                     UK Reality\nAGENT\n-  80,000           600
# 6477                   Saproperties\nAGENT\n-   1.6 L          2100
# 18907              MY HOMES GATEWAY\nAGENT\n0   36000          1560
# 11098                 Prema Housing\nAGENT\n-  40,000          1000
# 8825           Mahalaxmi Properties\nAGENT\n-   1.4 L          1500
# 15300    Amresh Property Ghansoli\nBUILDER\n-  11,390           670
# ...
