# %% [markdown]
# ### problem statement:

# %% [markdown]
# ##### import Required library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### load the cvs files

# %%
# mumbai city csv file:
mumbai=pd.read_csv('mumbai.csv')

# %%
# pune city csv file:
pune=pd.read_csv('pune.csv')

# %%
# Banglore city csv file:
Banglore=pd.read_csv('Banglore.csv')

# %%
# Chennai city csv file:
Chennai=pd.read_csv('Chennai.csv')

# %%
# Delhi city csv file:
Delhi=pd.read_csv('Delhi.csv')

# %%
# gurgaoncity csv file:
gurgaon=pd.read_csv('gurgaon.csv')

# %%
# gurgaoncity csv file:
hyderabad=pd.read_csv('hyderabad.csv')

# %%
# kolkata city csv file:
kolkata=pd.read_csv('kolkata.csv')

# %%
### merge alll above city into one dataframe:
city=pd.concat([mumbai,pune,Banglore,Chennai,Delhi,gurgaon,hyderabad,kolkata],ignore_index=True)

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 67311          Samim Baidya\nAGENT\n0  35,000          1250                2
# 67312            Houseindia\nAGENT\n0  10,000          1100                3
# 67313        TGE PROPERTIES\nAGENT\n0   6,500           500                1
# 67314           Vikas Kumar\nAGENT\n0  44,000          2750                3
# 67315          Sagar Realty\nAGENT\n0  30,000          1100                3
#
#           Deposit    Bathrooms            Facing                  Address  \
# 0      No Deposit  2 bathrooms  NorthEast facing             Ulwe, Mumbai
# 1      No Deposit  2 bathrooms  NorthEast facing             Ulwe, Mumbai
# 2      No Deposit  3 bathrooms  NorthEast facing             Ulwe, Mumbai
# 3      No Deposit  2 bathrooms               NaN   Kandivali West, Mumbai
# 4      No Deposit  3 bathrooms       East facing          Chembur, Mumbai
# ...           ...          ...               ...                      ...
# 67311  No Deposit  2 bathrooms      North facing  Salt Lake City, Kolkata
# 67312  No Deposit  2 bathrooms      South facing         Kalyani, Kolkata
# 67313  No Deposit  1 bathrooms               NaN      Baghajatin, Kolkata
# 67314  No Deposit  3 bathrooms      North facing       Sector 22, Kolkata
# 67315  No Deposit  2 bathrooms  SouthEast facing           Haltu, Kolkata
#
#                     Apartment Name          Status
# 0                        EV Castle     Unfurnished
# 1                              NaN     Unfurnished
# 2                              NaN  Semi-Furnished
# 3                   Atul Blue Arch     Unfurnished
# 4                     Godrej Prime  Semi-Furnished
# ...                            ...             ...
# 67311                          NaN  Semi-Furnished
# 67312                          NaN     Unfurnished
# 67313                          NaN     Unfurnished
# 67314                          NaN  Semi-Furnished
# 67315  Reputed Builder Avishikta 2  Semi-Furnished
#
# [67316 rows x 10 columns]

# %% [markdown]
# ## Data Preprossing

# %%
## taking random sample from dataset:
city.sample(50)
# Out:
#                                      broker_consultancy    Rent  Builtup Area  \
# 9629                 Mangal Murti Enterprises\nAGENT\n-  36,500          1150
# 11276                           Prema Housing\nAGENT\n-  40,000           832
# 51056                            Seller\nVERIFIED OWNER  16,000           500
# 56514                                   VENKY\nAGENT\n-  15,000          1000
# 21229                      Happiness Realtors\nAGENT\n0   18000           950
# 66103                            Seller\nVERIFIED OWNER   9,500           150
# 950    Star Properties Real Estate Consultant\nAGENT\n-  59,000          1000
# 47337                            Seller\nVERIFIED OWNER  48,000          1020
# 38792                       CK Home Solutions\nAGENT\n-  15,000           850
# 12539                       Naina Enterprises\nAGENT\n-  13,000           585
# 61564                        Individual Agent\nAGENT\n0  25,000          1350
# 8106                         Asian Properties\nAGENT\n-  48,000          1250
# 9289                             Jas Realtors\nAGENT\n-  90,000          1200
# 33427                            Krish Realty\nAGENT\n0  26,000           600
# 2957                                VSESTATES\nAGENT\n-  48,000           750
# 58038                            Seller\nVERIFIED OWNER  45,000          3000
# 8296              BEST DEAL Real Estate VIRAR\nAGENT\n-  16,000           900
# 1074                    Sai Iccha Enterprises\nAGENT\n-  15,000           623
# 52991                            Seller\nVERIFIED OWNER  22,000           700
# 39696                            Seller\nVERIFIED OWNER   8,500           500
# 10577                         Nikhil Parelkar\nAGENT\n-  75,000          1100
# 25273                            Seller\nVERIFIED OWNER  13,000          2000
# 4775                         Individual Agent\nAGENT\n-  35,000           750
# 51652                            Seller\nVERIFIED OWNER  12,000           700
# 43083                         Neon Properties\nAGENT\n0  65,000          1500
# 24603                            Seller\nVERIFIED OWNER  25,000           850
# 22932                            Seller\nVERIFIED OWNER  12,000           840
# 48333                            Access India\nAGENT\n0  2.75 L          3200
# 20081                            Seller\nVERIFIED OWNER   1.1 L          5000
# 51137                            Seller\nVERIFIED OWNER  45,000          2100
# 38686                        World Wide Infra\nAGENT\n0  90,000          2800
# 42755                       Adarsh Associates\nAGENT\n0  67,000          1000
# 66960                            Seller\nVERIFIED OWNER  30,000          1800
# 19433                             KDH REALITY\nAGENT\n0   24000          1250
# 20138                            Seller\nVERIFIED OWNER   11000           650
# 49064                            Seller\nVERIFIED OWNER   8,500           600
# 21384                             NISHA SINGH\nAGENT\n0   51000          2500
# 30657                            Seller\nVERIFIED OWNER   9,500          1200
# 41519                            Seller\nVERIFIED OWNER  11,000           750
# 41663                         Neon Properties\nAGENT\n-  65,000          1500
# 47525                  Mahadev Renting Expert\nAGENT\n-  32,500          1100
# 27073                            Seller\nVERIFIED OWNER  13,000          2000
# 24058                            Seller\nVERIFIED OWNER  20,000           550
# 3272                       Om Property Dealer\nAGENT\n-  74,000          1376
# 35798                            Seller\nVERIFIED OWNER  20,000           810
# 46551                           Modern Spaces\nAGENT\n-  85,000          2000
# 5156               Siddhi Vinayak Enterprises\nAGENT\n-  45,000          1850
# 38254                 Sweet Homes Real Estate\nAGENT\n-  50,000          2000
# 31567                            Seller\nVERIFIED OWNER  15,000          1100
# 63798                            Seller\nVERIFIED OWNER   7,000           460
#
#        appartment_type         Deposit    Bathrooms            Facing  \
# 9629                 2      No Deposit  2 bathrooms       East facing
# 11276                1   1.5 L deposit  1 bathrooms               NaN
# 51056                1      No Deposit  1 bathrooms               NaN
# 56514                1      No Deposit  1 bathrooms               NaN
# 21229                2      No Deposit  2 bathrooms               NaN
# 51652                 Sector 46, Gurgaon
# 43083                  Neeti Bagh, Delhi
# 24603           Kasavanahalli, Bangalore
# 22932             Nelamangala, Bangalore
# 48333                Sundar Nagar, Delhi
# 20081                Wadgaon Sheri, Pune
# 51137                 Sector 48, Gurgaon
# 38686                 Vasant Kunj, Delhi
# 42755           Sarvodaya Enclave, Delhi
# 66960                 Mourigram, Kolkata
# 19433                      Wagholi, Pune
# 20138                  Anand Nagar, Pune
# 49064                 Sector 24, Gurgaon
# 21384                    Tathawade, Pune
# 30657       Kithaganur Colony, Bangalore
# 41519                   DLF Farms, Delhi
# 41663                  Neeti Bagh, Delhi
# 47525                   Janakpuri, Delhi
# 27073               Gottigere, Bangalore
# 24058              Whitefield, Bangalore
# 3272               Borivali East, Mumbai
# 35798            Sector 13 Rohini, Delhi
# 46551                 Vasant Kunj, Delhi
# 5156                    Kharghar, Mumbai
# 38254                       Saket, Delhi
# 31567             Koramangala, Bangalore
# 63798                  Jadavpur, Kolkata
#
#                               Apartment Name          Status
# 9629                                     NaN       Furnished
# 11276                      Kaustubh Platinum     Unfurnished
# 51056                                    NaN       Furnished
# 56514                                    NaN  Semi-Furnished
# 21229            Majestique Manhattan Wing C  Semi-Furnished
# 66103                                    NaN       Furnished
# 950             Swaraj Homes Sai Complex CHS       Furnished
# 47337                                    NaN       Furnished
# 38792                                    NaN  Semi-Furnished
# 12539                  Lodha Casa Bella Gold  Semi-Furnished
# 61564                                    NaN  Semi-Furnished
# 8106            Lokhandwala Sapphire Heights     Unfurnished
# 9289                          Godrej Central       Furnished
# 33427                   Prestige Bella Vista       Furnished
# 2957                 Maitree Avalon Paradise     Unfurnished
# 58038                                    NaN       Furnished
# 8296   Rustomjee Global City Virar Avenue D1  Semi-Furnished
# 1074                                     NaN  Semi-Furnished
# 52991                                    NaN       Furnished
# 39696                                    NaN  Semi-Furnished
# 10577                    Sudarshan CHS Parel       Furnished
# 25273                                    NaN  Semi-Furnished
# 4775        Reputed Builder Lubna Apartments  Semi-Furnished
# 51652                                    NaN     Unfurnished
# 43083                                    NaN  Semi-Furnished
# 24603                                    NaN  Semi-Furnished
# 22932                         Tata New Haven  Semi-Furnished
# 48333                                    NaN  Semi-Furnished
# 20081                                    NaN     Unfurnished
# 51137                      Vipul World Plots       Furnished
# 38686              DDA DDA Sector B Pocket 9  Semi-Furnished
# 42755                                    NaN       Furnished
# 66960                                    NaN       Furnished
# 19433   Kolte Patil Ivy Apartment E V And VI  Semi-Furnished
# 20138                                    NaN  Semi-Furnished
# 49064                                    NaN       Furnished
# 21384             Pharande Puneville Phase I  Semi-Furnished
# 30657                                    NaN  Semi-Furnished
# 41519                                    NaN  Semi-Furnished
# 41663                                    NaN  Semi-Furnished
# 47525                     DDA Flat Janakpuri  Semi-Furnished
# 27073                                    NaN  Semi-Furnished
# 24058                                    NaN       Furnished
# 3272                         Gitanjali Tatva       Furnished
# 35798           Reputed Builder GS Apartment     Unfurnished
# 46551                  DDA Flats Vasant Kunj     Unfurnished
# 5156                                     NaN  Semi-Furnished
# 38254                                    NaN  Semi-Furnished
# 31567                                    NaN  Semi-Furnished
# 63798                                    NaN     Unfurnished

# %%
### In rent column data contain alphanumeric values like 1.5L,3.5L values we need to convert this into the numeric value

# %%
## conversion of rentcolumn into numeri type:
def convert_rent(rent):
    if "L" in rent:
        return int(float(rent.replace('L','').replace(',','').strip())*100000)                                           
    else:
        return int(float(rent.replace(',','').strip()))

# %%
city['Rent']=city['Rent'].apply(convert_rent)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  int64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 5.1+ MB

# %%
## conversion of Deposit column into the numeric type:
def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str) and 'L' in deposit:
        # Split on 'L', take the first part, convert to float, and multiply by 100000
        return float(deposit.split('L')[0]) * 100000
    else:
        # Handle other cases as needed
        return deposit

city['Deposit'] = city['Deposit'].apply(convert_deposit)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  int64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 5.1+ MB

# %%
## conversion of Deposit column into the numeric type:
def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str) and 'L' in deposit:
        # Split on 'L', take the first part, convert to float, and multiply by 100000
        return float(deposit.split('L')[0]) * 100000
    else:
        # Handle other cases as needed
        return deposit

city['Deposit'] = city['Deposit'].apply(convert_deposit)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  int64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 5.1+ MB

# %%
city(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 city(50)
#
# TypeError: 'DataFrame' object is not callable

# %%
city.sample(50)

# %%
## remove bathrooms from no_of bathroom:
def extract_first_number(x):
    if isinstance(x, str):
        # Split the string and convert the first part to float
        return float(x.split(' ')[0])
    elif isinstance(x, float):
        # If it's already a float, return it as is
        return x
    else:
        # Handle other cases (if any) or return NaN
        return float('nan')

city['Bathrooms'] = city['Bathrooms'].apply(extract_first_number)

# %%
city.info()

# %%
### spliting the adaress into the locality and city

# %%
city['City']=city['Address'].str.split(',').apply(lambda x:x[1])

# %%
city

# %%
city['locality']=city['Address'].str.split(',').apply(lambda x:x[0])

# %%
city.drop(columns=['Address'],inplace=True)

# %%
city

# %%
city.sample(15)

# %%
city['City'].value_counts().plot(kind='bar')

# %%
city['Status'].value_counts().plot(kind='bar')

# %%
city['Facing'].value_counts().plot(kind='bar')

# %%
city.describe()

# %%
city.drop(columns=['broker_consultancy'],inplace=True)

# %%
city

# %%
city.isna().sum()

# %%
city.drop(columns=['Address'],inplace=True)

# %%
city

# %%
city.sample(50
           )

# %%
def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str):
        # Remove commas and the word 'deposit', then strip any extra spaces
        deposit = deposit.replace(',', '').replace('deposit', '').strip()
        if 'L' in deposit:
            return int(float(deposit.replace('L', '').strip()) * 100000)
        else:
            return int(float(deposit))
    else:
        return int(deposit)  # Convert already numeric values to int

# Apply the function to the Deposit column
city['Deposit'] = city['Deposit'].apply(convert_deposit)

# %%
city

# %%
city.describe()

# %%
city.info()

# %%
city.isna().sum()

# %%
city.shape[0]
