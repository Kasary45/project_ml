# %%
import numpy as np
import pandas as pd

# %%
City=pd.read_csv('delhi.csv')

# %%
City
# Out:
#                       broker_consultancy    Rent  Area  appartment_type  \
# 0                 Seller\nVERIFIED OWNER    8500   500                2
# 1                 Seller\nVERIFIED OWNER   48000  1020                3
# 2                 Seller\nVERIFIED OWNER   20000   810                2
# 3                 Seller\nVERIFIED OWNER   11000   750                3
# 4                 Seller\nVERIFIED OWNER   20000  1300                3
# ...                                  ...     ...   ...              ...
# 14895            Modern Spaces\nAGENT\n0   85000  2000                3
# 14896        CK Home Solutions\nAGENT\n0   15000   850                2
# 14897             Access India\nAGENT\n0  2.75 L  3200                3
# 14898  Sweet Homes Real Estate\nAGENT\n0   50000  2000                4
# 14899        Adarsh Associates\nAGENT\n0   67000  1000                2
#
#               Deposit    Bathrooms            Facing  \
# 0          No Deposit  1 bathrooms  NorthWest facing
# 1          No Deposit  3 bathrooms      South facing
# 2          No Deposit  2 bathrooms               NaN
# 3          No Deposit  1 bathrooms               NaN
# 4          No Deposit  2 bathrooms               NaN
# ...               ...          ...               ...
# 14895      No Deposit  4 bathrooms               NaN
# 14896  15,000 deposit  2 bathrooms               NaN
# 14897  8.25 L deposit  4 bathrooms               NaN
# 14898      No Deposit  4 bathrooms      South facing
# 14899      No Deposit  2 bathrooms               NaN
#
#                         Address                Apartment Name          Status  \
# 0            Uttam Nagar, Delhi                           NaN  Semi-Furnished
# 1             Model Town, Delhi                           NaN       Furnished
# 2       Sector 13 Rohini, Delhi  Reputed Builder GS Apartment     Unfurnished
# 3              DLF Farms, Delhi                           NaN  Semi-Furnished
# 4            laxmi nagar, Delhi                           NaN       Furnished
# ...                         ...                           ...             ...
# 14895        Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 14896           Shahdara, Delhi                           NaN  Semi-Furnished
# 14897       Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 14898              Saket, Delhi                           NaN  Semi-Furnished
# 14899  Sarvodaya Enclave, Delhi                           NaN       Furnished
#
#       Unnamed: 10
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 14895         NaN
# 14896         NaN
# 14897         NaN
# 14898         NaN
# 14899         NaN
#
# [14900 rows x 11 columns]

# %%
City['location']=City['Address'].str.split(',').apply(lambda x:x[0])

# %%
City['City']=City['Address'].str.split(',').apply(lambda x:x[-1])

# %%
City
# Out:
#                       broker_consultancy    Rent  Area  appartment_type  \
# 0                 Seller\nVERIFIED OWNER    8500   500                2
# 1                 Seller\nVERIFIED OWNER   48000  1020                3
# 2                 Seller\nVERIFIED OWNER   20000   810                2
# 3                 Seller\nVERIFIED OWNER   11000   750                3
# 4                 Seller\nVERIFIED OWNER   20000  1300                3
# ...                                  ...     ...   ...              ...
# 14895            Modern Spaces\nAGENT\n0   85000  2000                3
# 14896        CK Home Solutions\nAGENT\n0   15000   850                2
# 14897             Access India\nAGENT\n0  2.75 L  3200                3
# 14898  Sweet Homes Real Estate\nAGENT\n0   50000  2000                4
# 14899        Adarsh Associates\nAGENT\n0   67000  1000                2
#
#               Deposit    Bathrooms            Facing  \
# 0          No Deposit  1 bathrooms  NorthWest facing
# 1          No Deposit  3 bathrooms      South facing
# 2          No Deposit  2 bathrooms               NaN
# 3          No Deposit  1 bathrooms               NaN
# 4          No Deposit  2 bathrooms               NaN
# ...               ...          ...               ...
# 14895      No Deposit  4 bathrooms               NaN
# 14896  15,000 deposit  2 bathrooms               NaN
# 14897  8.25 L deposit  4 bathrooms               NaN
# 14898      No Deposit  4 bathrooms      South facing
# 14899      No Deposit  2 bathrooms               NaN
#
#                         Address                Apartment Name          Status  \
# 0            Uttam Nagar, Delhi                           NaN  Semi-Furnished
# 1             Model Town, Delhi                           NaN       Furnished
# 2       Sector 13 Rohini, Delhi  Reputed Builder GS Apartment     Unfurnished
# 3              DLF Farms, Delhi                           NaN  Semi-Furnished
# 4            laxmi nagar, Delhi                           NaN       Furnished
# ...                         ...                           ...             ...
# 14895        Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 14896           Shahdara, Delhi                           NaN  Semi-Furnished
# 14897       Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 14898              Saket, Delhi                           NaN  Semi-Furnished
# 14899  Sarvodaya Enclave, Delhi                           NaN       Furnished
#
#       Unnamed: 10           location    City
# 0             NaN        Uttam Nagar   Delhi
# 1             NaN         Model Town   Delhi
# 2             NaN   Sector 13 Rohini   Delhi
# 3             NaN          DLF Farms   Delhi
# 4             NaN        laxmi nagar   Delhi
# ...           ...                ...     ...
# 14895         NaN        Vasant Kunj   Delhi
# 14896         NaN           Shahdara   Delhi
# 14897         NaN       Sundar Nagar   Delhi
# 14898         NaN              Saket   Delhi
# 14899         NaN  Sarvodaya Enclave   Delhi
#
# [14900 rows x 13 columns]

# %%
City.sample(15)
# Out:
#                      broker_consultancy    Rent  Area  appartment_type  \
# 13901            Seller\nVERIFIED OWNER   48000  1020                3
# 5009   Mahadev Renting Expert\nAGENT\n-   32500  1100                3
# 11331           Rana Property\nAGENT\n-   25000   950                3
# 8910         World Wide Infra\nAGENT\n0   90000  2800                4
# 5346             Seller\nVERIFIED OWNER   39000  1100                3
# 874             Residence Hub\nAGENT\n-   45000  1500                3
# 12822            Seller\nVERIFIED OWNER   20000   810                2
# 5353            Gaurav Dahiya\nAGENT\n-   28000  1100                3
# 2622             Seller\nVERIFIED OWNER   20000   810                2
# 1506             Seller\nVERIFIED OWNER   39000  1100                3
# 9148     MAA KALKA PROPERTIES\nAGENT\n0   45000   900                2
# 2769   Mahadev Renting Expert\nAGENT\n0   32500  1100                3
# 1093            Gaurav Dahiya\nAGENT\n0   28000  1100                3
# 13577            Access India\nAGENT\n-  2.75 L  3200                3
# 12655           Modern Spaces\nAGENT\n-   85000  2000                3
#
#               Deposit    Bathrooms        Facing  \
# 13901      No Deposit  3 bathrooms  South facing
# 5009       No Deposit  2 bathrooms           NaN
# 11331      No Deposit  2 bathrooms           NaN
# 8910       No Deposit  4 bathrooms           NaN
# 5346       No Deposit  2 bathrooms           NaN
# 874        No Deposit  3 bathrooms           NaN
# 12822      No Deposit  2 bathrooms           NaN
# 5353       No Deposit  2 bathrooms           NaN
# 2622       No Deposit  2 bathrooms           NaN
# 1506       No Deposit  2 bathrooms           NaN
# 9148       No Deposit  2 bathrooms           NaN
# 2769       No Deposit  2 bathrooms           NaN
# 1093       No Deposit  2 bathrooms           NaN
# 13577  8.25 L deposit  4 bathrooms           NaN
# 12655      No Deposit  4 bathrooms           NaN
#
#                                Address                Apartment Name  \
# 13901                Model Town, Delhi                           NaN
# 5009                  Janakpuri, Delhi            DDA Flat Janakpuri
# 11331                Govindpuri, Delhi                           NaN
# 8910                Vasant Kunj, Delhi     DDA DDA Sector B Pocket 9
# 5346                  Janakpuri, Delhi                           NaN
# 874    Freedom Fighters Enclave, Delhi                           NaN
# 12822          Sector 13 Rohini, Delhi  Reputed Builder GS Apartment
# 5353             Mansa Ram Park, Delhi                           NaN
# 2622           Sector 13 Rohini, Delhi  Reputed Builder GS Apartment
# 1506                  Janakpuri, Delhi                           NaN
# 9148            Lajpat Nagar II, Delhi                           NaN
# 2769                  Janakpuri, Delhi            DDA Flat Janakpuri
# 1093             Mansa Ram Park, Delhi                           NaN
# 13577              Sundar Nagar, Delhi                           NaN
# 12655               Vasant Kunj, Delhi         DDA Flats Vasant Kunj
#
#                Status Unnamed: 10                  location    City
# 13901       Furnished         NaN                Model Town   Delhi
# 5009   Semi-Furnished         NaN                 Janakpuri   Delhi
# 11331  Semi-Furnished         NaN                Govindpuri   Delhi
# 8910   Semi-Furnished         NaN               Vasant Kunj   Delhi
# 5346   Semi-Furnished         NaN                 Janakpuri   Delhi
# 874         Furnished         NaN  Freedom Fighters Enclave   Delhi
# 12822     Unfurnished         NaN          Sector 13 Rohini   Delhi
# 5353   Semi-Furnished         NaN            Mansa Ram Park   Delhi
# 2622      Unfurnished         NaN          Sector 13 Rohini   Delhi
# 1506   Semi-Furnished         NaN                 Janakpuri   Delhi
# 9148        Furnished         NaN           Lajpat Nagar II   Delhi
# 2769   Semi-Furnished         NaN                 Janakpuri   Delhi
# 1093   Semi-Furnished         NaN            Mansa Ram Park   Delhi
# 13577  Semi-Furnished         NaN              Sundar Nagar   Delhi
# 12655     Unfurnished         NaN               Vasant Kunj   Delhi

# %%
City.sample(50)
# Out:
#                       broker_consultancy    Rent  Area  appartment_type  \
# 8627           Neon Properties\nAGENT\n-   65000  1500                2
# 14200             Seller\nVERIFIED OWNER    8500   500                2
# 4701              Seller\nVERIFIED OWNER   48000  1020                3
# 5581              Seller\nVERIFIED OWNER   48000  1020                3
# 1057              Access India\nAGENT\n-  2.75 L  3200                3
# 10756        CK Home Solutions\nAGENT\n-   15000   850                2
# 9427           Neon Properties\nAGENT\n0   65000  1500                2
# 10445             Seller\nVERIFIED OWNER   35000  1200                3
# 9604              Seller\nVERIFIED OWNER   20000  1300                3
# 2283              Seller\nVERIFIED OWNER   11000   750                3
# 782               Seller\nVERIFIED OWNER   20000   810                2
# 4486              Seller\nVERIFIED OWNER   39000  1100                3
# 10575            Modern Spaces\nAGENT\n-   85000  2000                3
# 4672               R M Reality\nAGENT\n-  1.75 L  2700                4
# 3225              Seller\nVERIFIED OWNER   35000  1200                3
# 11861             Seller\nVERIFIED OWNER   48000  1020                3
# 11364             Seller\nVERIFIED OWNER   20000  1300                3
# 14112              R M Reality\nAGENT\n0  1.75 L  2700                4
# 10687          Neon Properties\nAGENT\n0   65000  1500                2
# 290           World Wide Infra\nAGENT\n0   90000  2800                4
# 2672               R M Reality\nAGENT\n0  1.75 L  2700                4
# 5177              Access India\nAGENT\n-  2.75 L  3200                3
# 12144             Seller\nVERIFIED OWNER   20000  1300                3
# 1873             Gaurav Dahiya\nAGENT\n0   28000  1100                3
# 5178   Sweet Homes Real Estate\nAGENT\n-   50000  2000                4
# 14797             Access India\nAGENT\n-  2.75 L  3200                3
# 12907          Neon Properties\nAGENT\n-   65000  1500                2
# 14321             Seller\nVERIFIED OWNER   48000  1020                3
# 9470          World Wide Infra\nAGENT\n-   90000  2800                4
# 8391             Rana Property\nAGENT\n-   25000   950                3
# 3544              Seller\nVERIFIED OWNER   20000  1300                3
# 13763             Seller\nVERIFIED OWNER   11000   750                3
# 6879         Adarsh Associates\nAGENT\n-   67000  1000                2
# 10932              R M Reality\nAGENT\n0  1.75 L  2700                4
# 8782              Seller\nVERIFIED OWNER   20000   810                2
# 4209    Mahadev Renting Expert\nAGENT\n0   32500  1100                3
# 12137             Access India\nAGENT\n-  2.75 L  3200                3
# 4133             Gaurav Dahiya\nAGENT\n-   28000  1100                3
# 10790         World Wide Infra\nAGENT\n-   90000  2800                4
# 6230          World Wide Infra\nAGENT\n0   90000  2800                4
# 14595            Modern Spaces\nAGENT\n0   85000  2000                3
# 2735             Modern Spaces\nAGENT\n-   85000  2000                3
# 4952               R M Reality\nAGENT\n-  1.75 L  2700                4
# 9310          World Wide Infra\nAGENT\n0   90000  2800                4
# 12663             Seller\nVERIFIED OWNER   11000   750                3
# 4728      MAA KALKA PROPERTIES\nAGENT\n0   45000   900                2
# 4151             Rana Property\nAGENT\n-   25000   950                3
# 5798   Sweet Homes Real Estate\nAGENT\n0   50000  2000                4
# 12460             Seller\nVERIFIED OWNER    8500   500                2
# 867            Neon Properties\nAGENT\n0   65000  1500                2
#
#               Deposit    Bathrooms            Facing  \
# 8627       No Deposit  2 bathrooms  NorthEast facing
# 14200      No Deposit  1 bathrooms  NorthWest facing
# 4701       No Deposit  3 bathrooms      South facing
# 5581       No Deposit  3 bathrooms      South facing
# 1057   8.25 L deposit  4 bathrooms               NaN
# 10756  15,000 deposit  2 bathrooms               NaN
# 9427       No Deposit  2 bathrooms  NorthEast facing
# 10445      No Deposit  2 bathrooms               NaN
# 9604       No Deposit  2 bathrooms               NaN
# 2283       No Deposit  1 bathrooms               NaN
# 782        No Deposit  2 bathrooms               NaN
# 4486       No Deposit  2 bathrooms               NaN
# 10575      No Deposit  4 bathrooms               NaN
# 4672       No Deposit  4 bathrooms               NaN
# 3225       No Deposit  2 bathrooms               NaN
# 11861      No Deposit  3 bathrooms      South facing
# 11364      No Deposit  2 bathrooms               NaN
# 14112      No Deposit  4 bathrooms               NaN
# 10687      No Deposit  2 bathrooms  NorthEast facing
# 290        No Deposit  4 bathrooms               NaN
# 2672       No Deposit  4 bathrooms               NaN
# 5177   8.25 L deposit  4 bathrooms               NaN
# 12144      No Deposit  2 bathrooms               NaN
# 1873       No Deposit  2 bathrooms               NaN
# 5178       No Deposit  4 bathrooms      South facing
# 14797  8.25 L deposit  4 bathrooms               NaN
# 12907      No Deposit  2 bathrooms  NorthEast facing
# 14321      No Deposit  3 bathrooms      South facing
# 9470       No Deposit  4 bathrooms               NaN
# 8391       No Deposit  2 bathrooms               NaN
# 3544       No Deposit  2 bathrooms               NaN
# 13763      No Deposit  1 bathrooms               NaN
# 6879       No Deposit  2 bathrooms               NaN
# 10932      No Deposit  4 bathrooms               NaN
# 8782       No Deposit  2 bathrooms               NaN
# 4209       No Deposit  2 bathrooms               NaN
# 12137  8.25 L deposit  4 bathrooms               NaN
# 4133       No Deposit  2 bathrooms               NaN
# 10790      No Deposit  4 bathrooms               NaN
# 6230       No Deposit  4 bathrooms               NaN
# 14595      No Deposit  4 bathrooms               NaN
# 2735       No Deposit  4 bathrooms               NaN
# 4952       No Deposit  4 bathrooms               NaN
# 9310       No Deposit  4 bathrooms               NaN
# 12663      No Deposit  1 bathrooms               NaN
# 4728       No Deposit  2 bathrooms               NaN
# 4151       No Deposit  2 bathrooms               NaN
# 5798       No Deposit  4 bathrooms      South facing
# 12460      No Deposit  1 bathrooms  NorthWest facing
# 867        No Deposit  2 bathrooms  NorthEast facing
#
#                         Address                Apartment Name          Status  \
# 8627          Neeti Bagh, Delhi                           NaN  Semi-Furnished
# 14200        Uttam Nagar, Delhi                           NaN  Semi-Furnished
# 4701          Model Town, Delhi                           NaN       Furnished
# 5581          Model Town, Delhi                           NaN       Furnished
# 1057        Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 10756           Shahdara, Delhi                           NaN  Semi-Furnished
# 9427          Neeti Bagh, Delhi                           NaN  Semi-Furnished
# 10445     Swasthya Vihar, Delhi                           NaN       Furnished
# 9604         laxmi nagar, Delhi                           NaN       Furnished
# 2283           DLF Farms, Delhi                           NaN  Semi-Furnished
# 782     Sector 13 Rohini, Delhi  Reputed Builder GS Apartment     Unfurnished
# 4486           Janakpuri, Delhi                           NaN  Semi-Furnished
# 10575        Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 4672     Greater Kailash, Delhi                           NaN  Semi-Furnished
# 3225      Swasthya Vihar, Delhi                           NaN       Furnished
# 11861         Model Town, Delhi                           NaN       Furnished
# 11364        laxmi nagar, Delhi                           NaN       Furnished
# 14112    Greater Kailash, Delhi                           NaN  Semi-Furnished
# 10687         Neeti Bagh, Delhi                           NaN  Semi-Furnished
# 290          Vasant Kunj, Delhi     DDA DDA Sector B Pocket 9  Semi-Furnished
# 2672     Greater Kailash, Delhi                           NaN  Semi-Furnished
# 5177        Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 12144        laxmi nagar, Delhi                           NaN       Furnished
# 1873      Mansa Ram Park, Delhi                           NaN  Semi-Furnished
# 5178               Saket, Delhi                           NaN  Semi-Furnished
# 14797       Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 12907         Neeti Bagh, Delhi                           NaN  Semi-Furnished
# 14321         Model Town, Delhi                           NaN       Furnished
# 9470         Vasant Kunj, Delhi     DDA DDA Sector B Pocket 9  Semi-Furnished
# 8391          Govindpuri, Delhi                           NaN  Semi-Furnished
# 3544         laxmi nagar, Delhi                           NaN       Furnished
# 13763          DLF Farms, Delhi                           NaN  Semi-Furnished
# 6879   Sarvodaya Enclave, Delhi                           NaN       Furnished
# 10932    Greater Kailash, Delhi                           NaN  Semi-Furnished
# 8782    Sector 13 Rohini, Delhi  Reputed Builder GS Apartment     Unfurnished
# 4209           Janakpuri, Delhi            DDA Flat Janakpuri  Semi-Furnished
# 12137       Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 4133      Mansa Ram Park, Delhi                           NaN  Semi-Furnished
# 10790        Vasant Kunj, Delhi     DDA DDA Sector B Pocket 9  Semi-Furnished
# 6230         Vasant Kunj, Delhi     DDA DDA Sector B Pocket 9  Semi-Furnished
# 14595        Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 2735         Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 4952     Greater Kailash, Delhi                           NaN  Semi-Furnished
# 9310         Vasant Kunj, Delhi     DDA DDA Sector B Pocket 9  Semi-Furnished
# 12663          DLF Farms, Delhi                           NaN  Semi-Furnished
# 4728     Lajpat Nagar II, Delhi                           NaN       Furnished
# 4151          Govindpuri, Delhi                           NaN  Semi-Furnished
# 5798               Saket, Delhi                           NaN  Semi-Furnished
# 12460        Uttam Nagar, Delhi                           NaN  Semi-Furnished
# 867           Neeti Bagh, Delhi                           NaN  Semi-Furnished
#
#       Unnamed: 10           location    City
# 8627          NaN         Neeti Bagh   Delhi
# 14200         NaN        Uttam Nagar   Delhi
# 4701          NaN         Model Town   Delhi
# 5581          NaN         Model Town   Delhi
# 1057          NaN       Sundar Nagar   Delhi
# 10756         NaN           Shahdara   Delhi
# 9427          NaN         Neeti Bagh   Delhi
# 10445         NaN     Swasthya Vihar   Delhi
# 9604          NaN        laxmi nagar   Delhi
# 2283          NaN          DLF Farms   Delhi
# 782           NaN   Sector 13 Rohini   Delhi
# 4486          NaN          Janakpuri   Delhi
# 10575         NaN        Vasant Kunj   Delhi
# 4672          NaN    Greater Kailash   Delhi
# 3225          NaN     Swasthya Vihar   Delhi
# 11861         NaN         Model Town   Delhi
# 11364         NaN        laxmi nagar   Delhi
# 14112         NaN    Greater Kailash   Delhi
# 10687         NaN         Neeti Bagh   Delhi
# 290           NaN        Vasant Kunj   Delhi
# 2672          NaN    Greater Kailash   Delhi
# 5177          NaN       Sundar Nagar   Delhi
# 12144         NaN        laxmi nagar   Delhi
# 1873          NaN     Mansa Ram Park   Delhi
# 5178          NaN              Saket   Delhi
# 14797         NaN       Sundar Nagar   Delhi
# 12907         NaN         Neeti Bagh   Delhi
# 14321         NaN         Model Town   Delhi
# 9470          NaN        Vasant Kunj   Delhi
# 8391          NaN         Govindpuri   Delhi
# 3544          NaN        laxmi nagar   Delhi
# 13763         NaN          DLF Farms   Delhi
# 6879          NaN  Sarvodaya Enclave   Delhi
# 10932         NaN    Greater Kailash   Delhi
# 8782          NaN   Sector 13 Rohini   Delhi
# 4209          NaN          Janakpuri   Delhi
# 12137         NaN       Sundar Nagar   Delhi
# 4133          NaN     Mansa Ram Park   Delhi
# 10790         NaN        Vasant Kunj   Delhi
# 6230          NaN        Vasant Kunj   Delhi
# 14595         NaN        Vasant Kunj   Delhi
# 2735          NaN        Vasant Kunj   Delhi
# 4952          NaN    Greater Kailash   Delhi
# 9310          NaN        Vasant Kunj   Delhi
# 12663         NaN          DLF Farms   Delhi
# 4728          NaN    Lajpat Nagar II   Delhi
# 4151          NaN         Govindpuri   Delhi
# 5798          NaN              Saket   Delhi
# 12460         NaN        Uttam Nagar   Delhi
# 867           NaN         Neeti Bagh   Delhi

# %%
## conversion of rentcolumn into numeric type:
def convert_rent(rent):
    if "L" in rent:
        return int(float(rent.replace('L','').replace(',','').strip())*100000)                                           
    else:
        return int(float(rent.replace(',','').strip()))

# %%
City['Rent']=City['Rent'].apply(convert_rent)

# %%
City
# Out:
#                       broker_consultancy    Rent  Area  appartment_type  \
# 0                 Seller\nVERIFIED OWNER    8500   500                2
# 1                 Seller\nVERIFIED OWNER   48000  1020                3
# 2                 Seller\nVERIFIED OWNER   20000   810                2
# 3                 Seller\nVERIFIED OWNER   11000   750                3
# 4                 Seller\nVERIFIED OWNER   20000  1300                3
# ...                                  ...     ...   ...              ...
# 14895            Modern Spaces\nAGENT\n0   85000  2000                3
# 14896        CK Home Solutions\nAGENT\n0   15000   850                2
# 14897             Access India\nAGENT\n0  275000  3200                3
# 14898  Sweet Homes Real Estate\nAGENT\n0   50000  2000                4
# 14899        Adarsh Associates\nAGENT\n0   67000  1000                2
#
#               Deposit    Bathrooms            Facing  \
# 0          No Deposit  1 bathrooms  NorthWest facing
# 1          No Deposit  3 bathrooms      South facing
# 2          No Deposit  2 bathrooms               NaN
# 3          No Deposit  1 bathrooms               NaN
# 4          No Deposit  2 bathrooms               NaN
# ...               ...          ...               ...
# 14895      No Deposit  4 bathrooms               NaN
# 14896  15,000 deposit  2 bathrooms               NaN
# 14897  8.25 L deposit  4 bathrooms               NaN
# 14898      No Deposit  4 bathrooms      South facing
# 14899      No Deposit  2 bathrooms               NaN
#
#                         Address                Apartment Name          Status  \
# 0            Uttam Nagar, Delhi                           NaN  Semi-Furnished
# 1             Model Town, Delhi                           NaN       Furnished
# 2       Sector 13 Rohini, Delhi  Reputed Builder GS Apartment     Unfurnished
# 3              DLF Farms, Delhi                           NaN  Semi-Furnished
# 4            laxmi nagar, Delhi                           NaN       Furnished
# ...                         ...                           ...             ...
# 14895        Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 14896           Shahdara, Delhi                           NaN  Semi-Furnished
# 14897       Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 14898              Saket, Delhi                           NaN  Semi-Furnished
# 14899  Sarvodaya Enclave, Delhi                           NaN       Furnished
#
#       Unnamed: 10           location    City
# 0             NaN        Uttam Nagar   Delhi
# 1             NaN         Model Town   Delhi
# 2             NaN   Sector 13 Rohini   Delhi
# 3             NaN          DLF Farms   Delhi
# 4             NaN        laxmi nagar   Delhi
# ...           ...                ...     ...
# 14895         NaN        Vasant Kunj   Delhi
# 14896         NaN           Shahdara   Delhi
# 14897         NaN       Sundar Nagar   Delhi
# 14898         NaN              Saket   Delhi
# 14899         NaN  Sarvodaya Enclave   Delhi
#
# [14900 rows x 13 columns]

# %%
City['Rent']=City['Rent'].astype(int)

# %%
City.dtypes
# Out:
# broker_consultancy    object
# Rent                   int64
# Area                   int64
# appartment_type        int64
# Deposit               object
# Bathrooms             object
# Facing                object
# Address               object
# Apartment Name        object
# Status                object
# Unnamed: 10           object
# location              object
# City                  object
# dtype: object

# %%
City['Rent/sqfit']=City['Rent']/City['Area']

# %%
City
# Out:
#                       broker_consultancy    Rent  Area  appartment_type  \
# 0                 Seller\nVERIFIED OWNER    8500   500                2
# 1                 Seller\nVERIFIED OWNER   48000  1020                3
# 2                 Seller\nVERIFIED OWNER   20000   810                2
# 3                 Seller\nVERIFIED OWNER   11000   750                3
# 4                 Seller\nVERIFIED OWNER   20000  1300                3
# ...                                  ...     ...   ...              ...
# 14895            Modern Spaces\nAGENT\n0   85000  2000                3
# 14896        CK Home Solutions\nAGENT\n0   15000   850                2
# 14897             Access India\nAGENT\n0  275000  3200                3
# 14898  Sweet Homes Real Estate\nAGENT\n0   50000  2000                4
# 14899        Adarsh Associates\nAGENT\n0   67000  1000                2
#
#               Deposit    Bathrooms            Facing  \
# 0          No Deposit  1 bathrooms  NorthWest facing
# 1          No Deposit  3 bathrooms      South facing
# 2          No Deposit  2 bathrooms               NaN
# 3          No Deposit  1 bathrooms               NaN
# 4          No Deposit  2 bathrooms               NaN
# ...               ...          ...               ...
# 14895      No Deposit  4 bathrooms               NaN
# 14896  15,000 deposit  2 bathrooms               NaN
# 14897  8.25 L deposit  4 bathrooms               NaN
# 14898      No Deposit  4 bathrooms      South facing
# 14899      No Deposit  2 bathrooms               NaN
#
#                         Address                Apartment Name          Status  \
# 0            Uttam Nagar, Delhi                           NaN  Semi-Furnished
# 1             Model Town, Delhi                           NaN       Furnished
# 2       Sector 13 Rohini, Delhi  Reputed Builder GS Apartment     Unfurnished
# 3              DLF Farms, Delhi                           NaN  Semi-Furnished
# 4            laxmi nagar, Delhi                           NaN       Furnished
# ...                         ...                           ...             ...
# 14895        Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 14896           Shahdara, Delhi                           NaN  Semi-Furnished
# 14897       Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 14898              Saket, Delhi                           NaN  Semi-Furnished
# 14899  Sarvodaya Enclave, Delhi                           NaN       Furnished
#
#       Unnamed: 10           location    City  Rent/sqfit
# 0             NaN        Uttam Nagar   Delhi   17.000000
# 1             NaN         Model Town   Delhi   47.058824
# 2             NaN   Sector 13 Rohini   Delhi   24.691358
# 3             NaN          DLF Farms   Delhi   14.666667
# 4             NaN        laxmi nagar   Delhi   15.384615
# ...           ...                ...     ...         ...
# 14895         NaN        Vasant Kunj   Delhi   42.500000
# 14896         NaN           Shahdara   Delhi   17.647059
# 14897         NaN       Sundar Nagar   Delhi   85.937500
# 14898         NaN              Saket   Delhi   25.000000
# 14899         NaN  Sarvodaya Enclave   Delhi   67.000000
#
# [14900 rows x 14 columns]

# %%
City.sample(150)
# Out:
#                       broker_consultancy    Rent  Area  appartment_type  \
# 11407          Neon Properties\nAGENT\n0   65000  1500                2
# 10218  Sweet Homes Real Estate\nAGENT\n-   50000  2000                4
# 11403             Seller\nVERIFIED OWNER   11000   750                3
# 2411             Rana Property\nAGENT\n-   25000   950                3
# 2217              Access India\nAGENT\n0  275000  3200                3
# ...                                  ...     ...   ...              ...
# 8187           Neon Properties\nAGENT\n-   65000  1500                2
# 7972               R M Reality\nAGENT\n0  175000  2700                4
# 6838   Sweet Homes Real Estate\nAGENT\n-   50000  2000                4
# 12730         World Wide Infra\nAGENT\n-   90000  2800                4
# 12316        CK Home Solutions\nAGENT\n-   15000   850                2
#
#               Deposit    Bathrooms            Facing                 Address  \
# 11407      No Deposit  2 bathrooms  NorthEast facing       Neeti Bagh, Delhi
# 10218      No Deposit  4 bathrooms      South facing            Saket, Delhi
# 11403      No Deposit  1 bathrooms               NaN        DLF Farms, Delhi
# 2411       No Deposit  2 bathrooms               NaN       Govindpuri, Delhi
# 2217   8.25 L deposit  4 bathrooms               NaN     Sundar Nagar, Delhi
# ...               ...          ...               ...                     ...
# 8187       No Deposit  2 bathrooms  NorthEast facing       Neeti Bagh, Delhi
# 7972       No Deposit  4 bathrooms               NaN  Greater Kailash, Delhi
# 6838       No Deposit  4 bathrooms      South facing            Saket, Delhi
# 12730      No Deposit  4 bathrooms               NaN      Vasant Kunj, Delhi
# 12316  15,000 deposit  2 bathrooms               NaN         Shahdara, Delhi
#
#                   Apartment Name          Status Unnamed: 10         location  \
# 11407                        NaN  Semi-Furnished         NaN       Neeti Bagh
# 10218                        NaN  Semi-Furnished         NaN            Saket
# 11403                        NaN  Semi-Furnished         NaN        DLF Farms
# 2411                         NaN  Semi-Furnished         NaN       Govindpuri
# 2217                         NaN  Semi-Furnished         NaN     Sundar Nagar
# ...                          ...             ...         ...              ...
# 8187                         NaN  Semi-Furnished         NaN       Neeti Bagh
# 7972                         NaN  Semi-Furnished         NaN  Greater Kailash
# 6838                         NaN  Semi-Furnished         NaN            Saket
# 12730  DDA DDA Sector B Pocket 9  Semi-Furnished         NaN      Vasant Kunj
# 12316                        NaN  Semi-Furnished         NaN         Shahdara
#
#          City  Rent/sqfit
# 11407   Delhi   43.333333
# 10218   Delhi   25.000000
# 11403   Delhi   14.666667
# 2411    Delhi   26.315789
# 2217    Delhi   85.937500
# ...       ...         ...
# 8187    Delhi   43.333333
# 7972    Delhi   64.814815
# 6838    Delhi   25.000000
# 12730   Delhi   32.142857
# 12316   Delhi   17.647059
#
# [150 rows x 14 columns]

# %%
City.describe()
# Out:
#                 Rent          Area  appartment_type    Rent/sqfit
# count   14900.000000  14900.000000     14900.000000  14900.000000
# mean    58950.000000   1414.000000         2.850000     36.155701
# std     61674.774317    727.557232         0.653857     18.534685
# min      8500.000000    500.000000         2.000000     14.666667
# 25%     23750.000000    937.500000         2.000000     24.922840
# 50%     42000.000000   1100.000000         3.000000     29.772727
# 75%     65500.000000   1625.000000         3.000000     44.264706
# max    275000.000000   3200.000000         4.000000     85.937500

# %%
filtered_city = City[City['Rent/sqfit'] <=25]

# %%
filtered_city.location.unique()
# Out:
# array(['Uttam Nagar', 'Sector 13 Rohini', 'DLF Farms', 'laxmi nagar',
#        'Shahdara', 'Saket'], dtype=object)

# %%
filtered_city1 = City[(City['Rent/sqfit'] > 25) & (City['Rent/sqfit'] <=45)]

# %%
filtered_city1.location.unique()
# Out:
# array(['Swasthya Vihar', 'Janakpuri', 'Neeti Bagh', 'Vasant Kunj',
#        'Govindpuri', 'Mansa Ram Park', 'Freedom Fighters Enclave'],
#       dtype=object)

# %%
filtered_city2 = City[City['Rent/sqfit'] >45]

# %%
filtered_city2.location.unique()
# Out:
# array(['Model Town', 'Lajpat Nagar II', 'Greater Kailash', 'Sundar Nagar',
#        'Sarvodaya Enclave'], dtype=object)

# %%
City.drop(columns=['location'],inplace=True)

# %%
City.drop(columns=['City'],inplace=True)

# %%
def add_rent_class(df):
    """
    Adds a 'class' column to the DataFrame based on the 'Rent/sqft' values.
    
    Parameters:
    df (pd.DataFrame): The DataFrame to which the 'class' column will be added.
    
    Returns:
    pd.DataFrame: The DataFrame with the new 'class' column.
    """
    def classify_rent(rent_sqfit):
        if rent_sqfit <= 25:
            return 'class3'
        elif 25 <= rent_sqfit <= 45:
            return 'class2'
        else:
            return 'class1'
    
    df['class'] = df['Rent/sqfit'].apply(classify_rent)
    return df

# %%
city_with_class = add_rent_class(City)

# %%
city_with_class
# Out:
#                       broker_consultancy    Rent  Area  appartment_type  \
# 0                 Seller\nVERIFIED OWNER    8500   500                2
# 1                 Seller\nVERIFIED OWNER   48000  1020                3
# 2                 Seller\nVERIFIED OWNER   20000   810                2
# 3                 Seller\nVERIFIED OWNER   11000   750                3
# 4                 Seller\nVERIFIED OWNER   20000  1300                3
# ...                                  ...     ...   ...              ...
# 14895            Modern Spaces\nAGENT\n0   85000  2000                3
# 14896        CK Home Solutions\nAGENT\n0   15000   850                2
# 14897             Access India\nAGENT\n0  275000  3200                3
# 14898  Sweet Homes Real Estate\nAGENT\n0   50000  2000                4
# 14899        Adarsh Associates\nAGENT\n0   67000  1000                2
#
#               Deposit    Bathrooms            Facing  \
# 0          No Deposit  1 bathrooms  NorthWest facing
# 1          No Deposit  3 bathrooms      South facing
# 2          No Deposit  2 bathrooms               NaN
# 3          No Deposit  1 bathrooms               NaN
# 4          No Deposit  2 bathrooms               NaN
# ...               ...          ...               ...
# 14895      No Deposit  4 bathrooms               NaN
# 14896  15,000 deposit  2 bathrooms               NaN
# 14897  8.25 L deposit  4 bathrooms               NaN
# 14898      No Deposit  4 bathrooms      South facing
# 14899      No Deposit  2 bathrooms               NaN
#
#                         Address                Apartment Name          Status  \
# 0            Uttam Nagar, Delhi                           NaN  Semi-Furnished
# 1             Model Town, Delhi                           NaN       Furnished
# 2       Sector 13 Rohini, Delhi  Reputed Builder GS Apartment     Unfurnished
# 3              DLF Farms, Delhi                           NaN  Semi-Furnished
# 4            laxmi nagar, Delhi                           NaN       Furnished
# ...                         ...                           ...             ...
# 14895        Vasant Kunj, Delhi         DDA Flats Vasant Kunj     Unfurnished
# 14896           Shahdara, Delhi                           NaN  Semi-Furnished
# 14897       Sundar Nagar, Delhi                           NaN  Semi-Furnished
# 14898              Saket, Delhi                           NaN  Semi-Furnished
# 14899  Sarvodaya Enclave, Delhi                           NaN       Furnished
#
#       Unnamed: 10  Rent/sqfit   class
# 0             NaN   17.000000  class3
# 1             NaN   47.058824  class1
# 2             NaN   24.691358  class3
# 3             NaN   14.666667  class3
# 4             NaN   15.384615  class3
# ...           ...         ...     ...
# 14895         NaN   42.500000  class2
# 14896         NaN   17.647059  class3
# 14897         NaN   85.937500  class1
# 14898         NaN   25.000000  class3
# 14899         NaN   67.000000  class1
#
# [14900 rows x 13 columns]

# %%
city_with_class.sample(150)
# Out:
#                       broker_consultancy   Rent  Area  appartment_type  \
# 6354             Residence Hub\nAGENT\n0  45000  1500                3
# 1716         CK Home Solutions\nAGENT\n0  15000   850                2
# 9847           Neon Properties\nAGENT\n0  65000  1500                2
# 12033            Gaurav Dahiya\nAGENT\n0  28000  1100                3
# 7783              Seller\nVERIFIED OWNER  11000   750                3
# ...                                  ...    ...   ...              ...
# 13108     MAA KALKA PROPERTIES\nAGENT\n-  45000   900                2
# 3505              Seller\nVERIFIED OWNER  35000  1200                3
# 923               Seller\nVERIFIED OWNER  11000   750                3
# 11458  Sweet Homes Real Estate\nAGENT\n-  50000  2000                4
# 3746              Seller\nVERIFIED OWNER  39000  1100                3
#
#               Deposit    Bathrooms            Facing  \
# 6354       No Deposit  3 bathrooms               NaN
# 1716   15,000 deposit  2 bathrooms               NaN
# 9847       No Deposit  2 bathrooms  NorthEast facing
# 12033      No Deposit  2 bathrooms               NaN
# 7783       No Deposit  1 bathrooms               NaN
# ...               ...          ...               ...
# 13108      No Deposit  2 bathrooms               NaN
# 3505       No Deposit  2 bathrooms               NaN
# 923        No Deposit  1 bathrooms               NaN
# 11458      No Deposit  4 bathrooms      South facing
# 3746       No Deposit  2 bathrooms               NaN
#
#                                Address Apartment Name          Status  \
# 6354   Freedom Fighters Enclave, Delhi            NaN       Furnished
# 1716                   Shahdara, Delhi            NaN  Semi-Furnished
# 9847                 Neeti Bagh, Delhi            NaN  Semi-Furnished
# 12033            Mansa Ram Park, Delhi            NaN  Semi-Furnished
# 7783                  DLF Farms, Delhi            NaN  Semi-Furnished
# ...                                ...            ...             ...
# 13108           Lajpat Nagar II, Delhi            NaN       Furnished
# 3505             Swasthya Vihar, Delhi            NaN       Furnished
# 923                   DLF Farms, Delhi            NaN  Semi-Furnished
# 11458                     Saket, Delhi            NaN  Semi-Furnished
# 3746                  Janakpuri, Delhi            NaN  Semi-Furnished
#
#       Unnamed: 10  Rent/sqfit   class
# 6354          NaN   30.000000  class2
# 1716          NaN   17.647059  class3
# 9847          NaN   43.333333  class2
# 12033         NaN   25.454545  class2
# 7783          NaN   14.666667  class3
# ...           ...         ...     ...
# 13108         NaN   50.000000  class1
# 3505          NaN   29.166667  class2
# 923           NaN   14.666667  class3
# 11458         NaN   25.000000  class3
# 3746          NaN   35.454545  class2
#
# [150 rows x 13 columns]

# %%
city_with_class.head(20)
# Out:
#                    broker_consultancy    Rent  Area  appartment_type  \
# 0              Seller\nVERIFIED OWNER    8500   500                2
# 1              Seller\nVERIFIED OWNER   48000  1020                3
# 2              Seller\nVERIFIED OWNER   20000   810                2
# 3              Seller\nVERIFIED OWNER   11000   750                3
# 4              Seller\nVERIFIED OWNER   20000  1300                3
# 5              Seller\nVERIFIED OWNER   35000  1200                3
# 6              Seller\nVERIFIED OWNER   39000  1100                3
# 7           Neon Properties\nAGENT\n-   65000  1500                2
# 8      MAA KALKA PROPERTIES\nAGENT\n-   45000   900                2
# 9    Mahadev Renting Expert\nAGENT\n-   32500  1100                3
# 10         World Wide Infra\nAGENT\n-   90000  2800                4
# 11            Rana Property\nAGENT\n-   25000   950                3
# 12              R M Reality\nAGENT\n-  175000  2700                4
# 13            Gaurav Dahiya\nAGENT\n-   28000  1100                3
# 14            Residence Hub\nAGENT\n-   45000  1500                3
# 15            Modern Spaces\nAGENT\n-   85000  2000                3
# 16        CK Home Solutions\nAGENT\n-   15000   850                2
# 17             Access India\nAGENT\n-  275000  3200                3
# 18  Sweet Homes Real Estate\nAGENT\n-   50000  2000                4
# 19        Adarsh Associates\nAGENT\n-   67000  1000                2
#
#            Deposit    Bathrooms            Facing  \
# 0       No Deposit  1 bathrooms  NorthWest facing
# 1       No Deposit  3 bathrooms      South facing
# 2       No Deposit  2 bathrooms               NaN
# 3       No Deposit  1 bathrooms               NaN
# 4       No Deposit  2 bathrooms               NaN
# 5       No Deposit  2 bathrooms               NaN
# 6       No Deposit  2 bathrooms               NaN
# 7       No Deposit  2 bathrooms  NorthEast facing
# 8       No Deposit  2 bathrooms               NaN
# 9       No Deposit  2 bathrooms               NaN
# 10      No Deposit  4 bathrooms               NaN
# 11      No Deposit  2 bathrooms               NaN
# 12      No Deposit  4 bathrooms               NaN
# 13      No Deposit  2 bathrooms               NaN
# 14      No Deposit  3 bathrooms               NaN
# 15      No Deposit  4 bathrooms               NaN
# 16  15,000 deposit  2 bathrooms               NaN
# 17  8.25 L deposit  4 bathrooms               NaN
# 18      No Deposit  4 bathrooms      South facing
# 19      No Deposit  2 bathrooms               NaN
#
#                             Address                Apartment Name  \
# 0                Uttam Nagar, Delhi                           NaN
# 1                 Model Town, Delhi                           NaN
# 2           Sector 13 Rohini, Delhi  Reputed Builder GS Apartment
# 3                  DLF Farms, Delhi                           NaN
# 4                laxmi nagar, Delhi                           NaN
# 5             Swasthya Vihar, Delhi                           NaN
# 6                  Janakpuri, Delhi                           NaN
# 7                 Neeti Bagh, Delhi                           NaN
# 8            Lajpat Nagar II, Delhi                           NaN
# 9                  Janakpuri, Delhi            DDA Flat Janakpuri
# 10               Vasant Kunj, Delhi     DDA DDA Sector B Pocket 9
# 11                Govindpuri, Delhi                           NaN
# 12           Greater Kailash, Delhi                           NaN
# 13            Mansa Ram Park, Delhi                           NaN
# 14  Freedom Fighters Enclave, Delhi                           NaN
# 15               Vasant Kunj, Delhi         DDA Flats Vasant Kunj
# 16                  Shahdara, Delhi                           NaN
# 17              Sundar Nagar, Delhi                           NaN
# 18                     Saket, Delhi                           NaN
# 19         Sarvodaya Enclave, Delhi                           NaN
#
#             Status Unnamed: 10  Rent/sqfit   class
# 0   Semi-Furnished         NaN   17.000000  class3
# 1        Furnished         NaN   47.058824  class1
# 2      Unfurnished         NaN   24.691358  class3
# 3   Semi-Furnished         NaN   14.666667  class3
# 4        Furnished         NaN   15.384615  class3
# 5        Furnished         NaN   29.166667  class2
# 6   Semi-Furnished         NaN   35.454545  class2
# 7   Semi-Furnished         NaN   43.333333  class2
# 8        Furnished         NaN   50.000000  class1
# 9   Semi-Furnished         NaN   29.545455  class2
# 10  Semi-Furnished         NaN   32.142857  class2
# 11  Semi-Furnished         NaN   26.315789  class2
# 12  Semi-Furnished         NaN   64.814815  class1
# 13  Semi-Furnished         NaN   25.454545  class2
# 14       Furnished         NaN   30.000000  class2
# 15     Unfurnished         NaN   42.500000  class2
# 16  Semi-Furnished         NaN   17.647059  class3
# 17  Semi-Furnished         NaN   85.937500  class1
# 18  Semi-Furnished         NaN   25.000000  class3
# 19       Furnished         NaN   67.000000  class1

# %%
city_with_class.to_csv('Delhi_class.csv', index=False)
