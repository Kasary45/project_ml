# %% [markdown]
# ### problem statement:

# %% [markdown]
# ##### import Required library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### load the cvs files

# %%
# mumbai city csv file:
mumbai=pd.read_csv('mumbai.csv')

# %%
# pune city csv file:
pune=pd.read_csv('pune.csv')

# %%
# Banglore city csv file:
Banglore=pd.read_csv('Banglore.csv')

# %%
# Chennai city csv file:
Chennai=pd.read_csv('Chennai.csv')

# %%
# Delhi city csv file:
Delhi=pd.read_csv('Delhi.csv')

# %%
# gurgaoncity csv file:
gurgaon=pd.read_csv('gurgaon.csv')

# %%
# gurgaoncity csv file:
hyderabad=pd.read_csv('hyderabad.csv')

# %%
# kolkata city csv file:
kolkata=pd.read_csv('kolkata.csv')

# %%
### merge alll above city into one dataframe:
city=pd.concat([mumbai,pune,Banglore,Chennai,Delhi,gurgaon,hyderabad,kolkata],ignore_index=True)

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 67311          Samim Baidya\nAGENT\n0  35,000          1250                2
# 67312            Houseindia\nAGENT\n0  10,000          1100                3
# 67313        TGE PROPERTIES\nAGENT\n0   6,500           500                1
# 67314           Vikas Kumar\nAGENT\n0  44,000          2750                3
# 67315          Sagar Realty\nAGENT\n0  30,000          1100                3
#
#           Deposit    Bathrooms            Facing                  Address  \
# 0      No Deposit  2 bathrooms  NorthEast facing             Ulwe, Mumbai
# 1      No Deposit  2 bathrooms  NorthEast facing             Ulwe, Mumbai
# 2      No Deposit  3 bathrooms  NorthEast facing             Ulwe, Mumbai
# 3      No Deposit  2 bathrooms               NaN   Kandivali West, Mumbai
# 4      No Deposit  3 bathrooms       East facing          Chembur, Mumbai
# ...           ...          ...               ...                      ...
# 67311  No Deposit  2 bathrooms      North facing  Salt Lake City, Kolkata
# 67312  No Deposit  2 bathrooms      South facing         Kalyani, Kolkata
# 67313  No Deposit  1 bathrooms               NaN      Baghajatin, Kolkata
# 67314  No Deposit  3 bathrooms      North facing       Sector 22, Kolkata
# 67315  No Deposit  2 bathrooms  SouthEast facing           Haltu, Kolkata
#
#                     Apartment Name          Status
# 0                        EV Castle     Unfurnished
# 1                              NaN     Unfurnished
# 2                              NaN  Semi-Furnished
# 3                   Atul Blue Arch     Unfurnished
# 4                     Godrej Prime  Semi-Furnished
# ...                            ...             ...
# 67311                          NaN  Semi-Furnished
# 67312                          NaN     Unfurnished
# 67313                          NaN     Unfurnished
# 67314                          NaN  Semi-Furnished
# 67315  Reputed Builder Avishikta 2  Semi-Furnished
#
# [67316 rows x 10 columns]

# %% [markdown]
# ## Data Preprossing

# %%
## taking random sample from dataset:
city.sample(50)
# Out:
#                           broker_consultancy    Rent  Builtup Area  \
# 63684                 Mondal Homes\nAGENT\n0  40,000          2200
# 4223             Dhirubhai Estates\nAGENT\n-  1.25 L          1600
# 66340                 Seller\nVERIFIED OWNER  30,000          1800
# 51167                 Seller\nVERIFIED OWNER  15,000          1250
# 64980                 Seller\nVERIFIED OWNER  30,000          1800
# 37697                 Seller\nVERIFIED OWNER  48,000          1020
# 36520                 Seller\nVERIFIED OWNER  20,000          1300
# 10211                 A Z Realtors\nAGENT\n-  78,000          1100
# 15150                     Vaibhav Pal\nOWNER  16,000           275
# 40358                 Seller\nVERIFIED OWNER  20,000           810
# 27861                 Seller\nVERIFIED OWNER  65,000          1650
# 23211                 Seller\nVERIFIED OWNER  14,000           450
# 17769           Happiness Realtors\nAGENT\n-   18000           950
# 66865        Silver Key Properties\nAGENT\n0  25,000           999
# 55702                 Seller\nVERIFIED OWNER  20,000          1800
# 16526       Vastupurti Real Estate\nAGENT\n-   30000          1300
# 57464             Individual Agent\nAGENT\n-  25,000          1350
# 38684         MAA KALKA PROPERTIES\nAGENT\n0  45,000           900
# 5350            Future Enterprises\nAGENT\n-  1.97 L          2000
# 43815            Adarsh Associates\nAGENT\n-  67,000          1000
# 36891                Modern Spaces\nAGENT\n-  85,000          2000
# 3815               Property Master\nAGENT\n-  10,000           610
# 23498                 Seller\nVERIFIED OWNER  20,000           550
# 9023           Vinayak Real Estate\nAGENT\n-  42,000           725
# 55265                       Ishaan\nAGENT\n-  50,000          2050
# 49723                 Seller\nVERIFIED OWNER  19,000           450
# 37846             World Wide Infra\nAGENT\n-  90,000          2800
# 45809                Gaurav Dahiya\nAGENT\n0  28,000          1100
# 34333                 Access India\nAGENT\n-  2.75 L          3200
# 11593               Navkar Estates\nAGENT\n-  42,000          1248
# 42293                 Access India\nAGENT\n-  2.75 L          3200
# 30359                 Seller\nVERIFIED OWNER  32,800           550
# 10786  KN Builders And Real Estate\nAGENT\n-  55,000           650
# 39780                 Seller\nVERIFIED OWNER  20,000          1300
# 12757                Ugam Property\nAGENT\n-  22,000          1100
# 23315                 Seller\nVERIFIED OWNER   6,500           350
# 61008          SYNERGY CONSULTANTS\nAGENT\n0  42,000          1886
# 38030                Residence Hub\nAGENT\n-  45,000          1500
# 46586             World Wide Infra\nAGENT\n-  90,000          2800
# 41952            CK Home Solutions\nAGENT\n-  15,000           850
# 66467                   Sanjay Sah\nAGENT\n0  20,000          1400
# 7943                SSC Consultant\nAGENT\n-   1.9 L          1802
# 27270                 Seller\nVERIFIED OWNER  11,000          1250
# 13821       Arjunraje Estate Agent\nAGENT\n-  32,000           690
# 38044         MAA KALKA PROPERTIES\nAGENT\n0  45,000           900
# 42536                 Seller\nVERIFIED OWNER   8,500           500
# 17144                  NISHA SINGH\nAGENT\n0   51000          2500
# 15954                    FS Realty\nAGENT\n0   26000           950
# 28628                 Seller\nVERIFIED OWNER   9,500           600
# 2245       Nine Yards Lease Assist\nAGENT\n-  14,000           550
#
#        appartment_type         Deposit    Bathrooms            Facing  \
# 63684                4      No Deposit  4 bathrooms               NaN
# 4223                 3      No Deposit  4 bathrooms      North facing
# 66340                3      No Deposit  3 bathrooms               NaN
# 51167                2      No Deposit  2 bathrooms       East facing
# 64980                3      No Deposit  3 bathrooms               NaN
# 37697                3      No Deposit  3 bathrooms      South facing
# 36520                3      No Deposit  2 bathrooms               NaN
# 10211                2      No Deposit  2 bathrooms       West facing
# 15150                1  50,000 deposit  2 bathrooms               NaN
# 40358                2      No Deposit  2 bathrooms               NaN
# 27861                3      No Deposit  3 bathrooms               NaN
# 23211                1      No Deposit  1 bathrooms               NaN
# 17769                2      No Deposit  2 bathrooms               NaN
# 66865                2      No Deposit  2 bathrooms       East facing
# 55702                3      No Deposit  3 bathrooms               NaN
# 16526                3      No Deposit  3 bathrooms       East facing
# 57464                2      No Deposit  2 bathrooms               NaN
# 38684                2      No Deposit  2 bathrooms               NaN
# 5350                 3      No Deposit  3 bathrooms               NaN
# 43815                2      No Deposit  2 bathrooms               NaN
# 36891                3      No Deposit  4 bathrooms               NaN
# 3815                 1      No Deposit  1 bathrooms               NaN
# 23498                1      No Deposit  1 bathrooms       West facing
# 9023                 2      No Deposit  2 bathrooms               NaN
# 55265                3      No Deposit  3 bathrooms       East facing
# 49723                1      No Deposit  1 bathrooms       West facing
# 37846                4      No Deposit  4 bathrooms               NaN
# 45809                3      No Deposit  2 bathrooms               NaN
# 34333                3  8.25 L deposit  4 bathrooms               NaN
# 11593                3      No Deposit  2 bathrooms       East facing
# 42293                3  8.25 L deposit  4 bathrooms               NaN
# 30359                1      No Deposit  1 bathrooms       East facing
# 10786                1      No Deposit  1 bathrooms       West facing
# 39780                3      No Deposit  2 bathrooms               NaN
# 12757                2     1 L deposit  2 bathrooms               NaN
# 23315                1      No Deposit  1 bathrooms               NaN
# 61008                3      No Deposit  3 bathrooms               NaN
# 38030                3      No Deposit  3 bathrooms               NaN
# 46586                4      No Deposit  4 bathrooms               NaN
# 41952                2  15,000 deposit  2 bathrooms               NaN
# 66467                3      No Deposit  2 bathrooms               NaN
# 7943                 3      No Deposit  4 bathrooms       East facing
# 27270                2      No Deposit  1 bathrooms      North facing
# 13821                1   1.5 L deposit  2 bathrooms               NaN
# 38044                2      No Deposit  2 bathrooms               NaN
# 42536                2      No Deposit  1 bathrooms  NorthWest facing
# 17144                5      No Deposit  5 bathrooms       West facing
# 15954                2      No Deposit  2 bathrooms       East facing
# 28628                1      No Deposit  1 bathrooms               NaN
# 2245                 2      No Deposit  2 bathrooms  SouthWest facing
#
#                                     Address  \
# 63684                     New Town, Kolkata
# 4223                           Juhu, Mumbai
# 66340                    Mourigram, Kolkata
# 51167                    Sector 69, Gurgaon
# 64980                    Mourigram, Kolkata
# 37697                     Model Town, Delhi
# 36520                    laxmi nagar, Delhi
# 10211                    Malad West, Mumbai
# 15150                    Prabhadevi, Mumbai
# 40358               Sector 13 Rohini, Delhi
# 27861  Sarjapur Road Post Railway Crossing,
# 23211                Munnekollal, Bangalore
# 17769                         Wagholi, Pune
# 66865                     New Town, Kolkata
# 55702                      Uppal, Hyderabad
# 16526                  Vadgaon Budruk, Pune
# 57464     Nallagandla Gachibowli, Hyderabad
# 38684                Lajpat Nagar II, Delhi
# 5350                     Prabhadevi, Mumbai
# 43815              Sarvodaya Enclave, Delhi
# 36891                    Vasant Kunj, Delhi
# 3815                   Naigaon East, Mumbai
# 23498                 Whitefield, Bangalore
# 9023                   Dahisar East, Mumbai
# 55265                   Shaikpet, Hyderabad
# 49723                   Sector 36A, Gurgaon
# 37846                    Vasant Kunj, Delhi
# 45809                 Mansa Ram Park, Delhi
# 34333                   Sundar Nagar, Delhi
# 11593                   Mulund West, Mumbai
# 42293                   Sundar Nagar, Delhi
# 30359                  Bellandur, Bangalore
# 10786                   Bandra West, Mumbai
# 39780                    laxmi nagar, Delhi
# 12757                      Kharghar, Mumbai
# 23315                J. P. Nagar, Bangalore
# 61008               Nanakramguda, Hyderabad
# 38030       Freedom Fighters Enclave, Delhi
# 46586                    Vasant Kunj, Delhi
# 41952                       Shahdara, Delhi
# 66467                     New Town, Kolkata
# 7943                    Lower Parel, Mumbai
# 27270           Ramamurthy Nagar, Bangalore
# 13821                 Borivali West, Mumbai
# 38044                Lajpat Nagar II, Delhi
# 42536                    Uttam Nagar, Delhi
# 17144                       Tathawade, Pune
# 15954                         Dhanori, Pune
# 28628           Electronics City, Bangalore
# 2245                      Dombivali, Mumbai
#
#                                 Apartment Name          Status
# 63684                   Sanjeeva Sanjeeva Town  Semi-Furnished
# 4223                                       NaN       Furnished
# 66340                                      NaN       Furnished
# 51167                                      NaN  Semi-Furnished
# 64980                                      NaN       Furnished
# 37697                                      NaN       Furnished
# 36520                                      NaN       Furnished
# 10211             Sheth Auris Serenity Tower 2  Semi-Furnished
# 15150                                      NaN     Unfurnished
# 40358             Reputed Builder GS Apartment     Unfurnished
# 27861                            Ahad Euphoria  Semi-Furnished
# 23211                                      NaN  Semi-Furnished
# 17769              Majestique Manhattan Wing C  Semi-Furnished
# 66865               Elita Garden Vista Phase 2  Semi-Furnished
# 55702                                      NaN       Furnished
# 16526             Tirupati Welworth Bluescapes  Semi-Furnished
# 57464                                      NaN  Semi-Furnished
# 38684                                      NaN       Furnished
# 5350                                       NaN       Furnished
# 43815                                      NaN       Furnished
# 36891                    DDA Flats Vasant Kunj     Unfurnished
# 3815   Sunteck West World 2 Tivri Naigaon East     Unfurnished
# 23498                                      NaN       Furnished
# 9023                                       NaN       Furnished
# 55265                                      NaN  Semi-Furnished
# 49723                                   AVL 36       Furnished
# 37846                DDA DDA Sector B Pocket 9  Semi-Furnished
# 45809                                      NaN  Semi-Furnished
# 34333                                      NaN  Semi-Furnished
# 11593                Wadhwa Atmosphere Phase 1  Semi-Furnished
# 42293                                      NaN  Semi-Furnished
# 30359                                      NaN       Furnished
# 10786          Swaraj Homes Windmere Apartment     Unfurnished
# 39780                                      NaN       Furnished
# 12757    Reputed Builder Jalvayu Vihar Phase 1     Unfurnished
# 23315                                      NaN  Semi-Furnished
# 61008                       Pacifica Hillcrest     Unfurnished
# 38030                                      NaN       Furnished
# 46586                DDA DDA Sector B Pocket 9  Semi-Furnished
# 41952                                      NaN  Semi-Furnished
# 66467  Danish Veeyu Coperative Housing Society  Semi-Furnished
# 7943                      Marathon Nextgen Era       Furnished
# 27270                                      NaN  Semi-Furnished
# 13821                           Ajmera Regalia       Furnished
# 38044                                      NaN       Furnished
# 42536                                      NaN  Semi-Furnished
# 17144               Pharande Puneville Phase I  Semi-Furnished
# 15954                   Raojee Palladium Homes     Unfurnished
# 28628                                      NaN  Semi-Furnished
# 2245   Runwal Gardens Phase 2 Bldg No 18 To 23     Unfurnished

# %%
### In rent column data contain alphanumeric values like 1.5L,3.5L values we need to convert this into the numeric value

# %%
## conversion of rentcolumn into numeri type:
def convert_rent(rent):
    if "L" in rent:
        return int(float(rent.replace('L','').replace(',','').strip())*100000)                                           
    else:
        return int(float(rent.replace(',','').strip()))

# %%
city['Rent']=city['Rent'].apply(convert_rent)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  int64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 5.1+ MB

# %%
## conversion of Deposit column into the numeric type:
def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str) and 'L' in deposit:
        # Split on 'L', take the first part, convert to float, and multiply by 100000
        return float(deposit.split('L')[0]) * 100000
    else:
        # Handle other cases as needed
        return deposit

city['Deposit'] = city['Deposit'].apply(convert_deposit)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  int64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 5.1+ MB

# %%
def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str):
        # Remove commas and the word 'deposit', then strip any extra spaces
        deposit = deposit.replace(',', '').replace('deposit', '').strip()
        if 'L' in deposit:
            return int(float(deposit.replace('L', '').strip()) * 100000)
        else:
            return int(float(deposit))
    else:
        return int(deposit)  # Convert already numeric values to int

# Apply the function to the Deposit column
city['Deposit'] = city['Deposit'].apply(convert_deposit)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  int64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  int64
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 5.1+ MB

# %%
city.sample(50)
# Out:
#                          broker_consultancy    Rent  Builtup Area  \
# 21791         Melange Consultancy\nAGENT\n0   48000          1300
# 16124                 NISHA SINGH\nAGENT\n0   51000          2500
# 42312           CK Home Solutions\nAGENT\n-   15000           850
# 29700                Seller\nVERIFIED OWNER   18000           550
# 48807                Seller\nVERIFIED OWNER   15000          1250
# 10505  Amresh Property Ghansoli\nBUILDER\n-   21000           684
# 302           Satguru Real Estate\nAGENT\n-    9000           789
# 4649             Individual Agent\nAGENT\n-   50000           625
# 8857                    S K Group\nAGENT\n-   18000          1000
# 24976                Seller\nVERIFIED OWNER   21000           550
# 13835              Picasso Realty\nAGENT\n-  135000           800
# 26720                Seller\nVERIFIED OWNER   18000           550
# 55611               Priya Rentals\nAGENT\n-   26000          1300
# 41584        MAA KALKA PROPERTIES\nAGENT\n0   45000           900
# 28884                Seller\nVERIFIED OWNER    8000           300
# 20454                   FS Realty\nAGENT\n0   26000           950
# 42402                Seller\nVERIFIED OWNER   39000          1100
# 63442                Seller\nVERIFIED OWNER   18000          1200
# 22757                Seller\nVERIFIED OWNER   12000           906
# 40353                Access India\nAGENT\n-  275000          3200
# 8064            Rajesh Properties\nAGENT\n-  150000          1000
# 19223               Primus Realty\nAGENT\n0   41000          1630
# 28942                Seller\nVERIFIED OWNER   18000          1000
# 41091               Modern Spaces\nAGENT\n-   85000          2000
# 25903                Seller\nVERIFIED OWNER   25000           850
# 8588            Urbanwalls Realty\nAGENT\n-   40000           800
# 53335                Seller\nVERIFIED OWNER   35000          2400
# 27131                Seller\nVERIFIED OWNER   14000           450
# 49758                Seller\nVERIFIED OWNER   10000           300
# 52196                Seller\nVERIFIED OWNER   16000           500
# 56297                Seller\nVERIFIED OWNER   16000          1100
# 47886            World Wide Infra\nAGENT\n-   90000          2800
# 65255                Sagar Realty\nAGENT\n0   30000          1100
# 17198                Seller\nVERIFIED OWNER   11000           650
# 4804       Complete Property Zone\nAGENT\n-   38000           875
# 30427                Seller\nVERIFIED OWNER   15000          1100
# 37145      Mahadev Renting Expert\nAGENT\n0   32500          1100
# 534             Swagat Properties\nAGENT\n-   22000           572
# 9176                      Azuroin\nAGENT\n-  150000          1100
# 63233                  SG RENTALS\nAGENT\n-   30000          1200
# 10895     Nestaway\nAGENT\n5.0\n827 Ratings   40000          1100
# 39429               Gaurav Dahiya\nAGENT\n0   28000          1100
# 23005                Seller\nVERIFIED OWNER    7000          1000
# 55081                Seller\nVERIFIED OWNER   30000          2400
# 52426                Seller\nVERIFIED OWNER   60000          2300
# 59593                  SG RENTALS\nAGENT\n0   30000          1200
# 42017                Seller\nVERIFIED OWNER   48000          1020
# 20652                 A Realities\nAGENT\n0   23000          1000
# 55088         SYNERGY CONSULTANTS\nAGENT\n-   42000          1886
# 51763                Seller\nVERIFIED OWNER   19000           450
#
#        appartment_type  Deposit    Bathrooms            Facing  \
# 21791                2        0  2 bathrooms               NaN
# 16124                5        0  5 bathrooms       West facing
# 42312                2    15000  2 bathrooms               NaN
# 29700                1        0  1 bathrooms       East facing
# 48807                2        0  2 bathrooms       East facing
# 10505                1    60000  2 bathrooms               NaN
# 302                  2        0  2 bathrooms               NaN
# 4649                 1        0  1 bathrooms       East facing
# 8857                 2        0  2 bathrooms  NorthEast facing
# 24976                1        0  1 bathrooms      North facing
# 13835                2   750000  2 bathrooms               NaN
# 26720                1        0  1 bathrooms       East facing
# 55611                2        0  2 bathrooms       West facing
# 41584                2        0  2 bathrooms               NaN
# 28884                1        0  1 bathrooms               NaN
# 20454                2        0  2 bathrooms       East facing
# 42402                3        0  2 bathrooms               NaN
# 63442                3        0  2 bathrooms               NaN
# 22757                2        0  2 bathrooms               NaN
# 40353                3   825000  4 bathrooms               NaN
# 8064                 2   700000  2 bathrooms               NaN
# 19223                3        0  3 bathrooms               NaN
# 28942                2        0  2 bathrooms               NaN
# 41091                3        0  4 bathrooms               NaN
# 25903                2        0  2 bathrooms       East facing
# 8588                 1        0  1 bathrooms       West facing
# 53335                3        0  2 bathrooms               NaN
# 27131                1        0  1 bathrooms               NaN
# 49758                1        0  1 bathrooms               NaN
# 52196                1        0  1 bathrooms               NaN
# 56297                2        0  2 bathrooms               NaN
# 47886                4        0  4 bathrooms               NaN
# 65255                3        0  2 bathrooms  SouthEast facing
# 17198                1        0  1 bathrooms               NaN
# 4804                 2        0  2 bathrooms       East facing
# 30427                2        0  2 bathrooms               NaN
# 37145                3        0  2 bathrooms               NaN
# 534                  2        0  2 bathrooms       East facing
# 9176                 2        0  2 bathrooms  NorthEast facing
# 63233                2        0  2 bathrooms               NaN
# 10895                2        0  2 bathrooms               NaN
# 39429                3        0  2 bathrooms               NaN
# 23005                1        0  1 bathrooms               NaN
# 55081                4        0  4 bathrooms               NaN
# 52426                4        0  4 bathrooms       East facing
# 59593                2        0  2 bathrooms               NaN
# 42017                3        0  3 bathrooms      South facing
# 20652                2        0  2 bathrooms       West facing
# 55088                3        0  3 bathrooms               NaN
# 51763                1        0  1 bathrooms       West facing
#
#                                        Address  \
# 21791                           Hadapsar, Pune
# 16124                          Tathawade, Pune
# 42312                          Shahdara, Delhi
# 29700               Krishnarajapura, Bangalore
# 48807                       Sector 69, Gurgaon
# 10505                         Ghansoli, Mumbai
# 302                             Taloja, Mumbai
# 4649                      Andheri West, Mumbai
# 8857                              Ulwe, Mumbai
# 24976                    Whitefield, Bangalore
# 13835                        Khar West, Mumbai
# 26720               Krishnarajapura, Bangalore
# 55611                      Kondapur, Hyderabad
# 41584                   Lajpat Nagar II, Delhi
# 28884                 Kasavanahalli, Bangalore
# 20454                            Dhanori, Pune
# 42402                         Janakpuri, Delhi
# 63442                      Santoshpur, Kolkata
# 22757                           Lohegaon, Pune
# 40353                      Sundar Nagar, Delhi
# 8064                      Andheri West, Mumbai
# 19223                      Mohammed wadi, Pune
# 28942               byatarayanapura, Bangalore
# 41091                       Vasant Kunj, Delhi
# 25903                 Kasavanahalli, Bangalore
# 8588                        Malad West, Mumbai
# 53335                       Sector 30, Gurgaon
# 27131                   Munnekollal, Bangalore
# 49758                        Sector 9, Gurgaon
# 52196                       Sector 31, Gurgaon
# 56297                   Toli Chowki, Hyderabad
# 47886                       Vasant Kunj, Delhi
# 65255                           Haltu, Kolkata
# 17198                        Anand Nagar, Pune
# 4804                     Goregaon East, Mumbai
# 30427                   Koramangala, Bangalore
# 37145                         Janakpuri, Delhi
# 534                         Thane West, Mumbai
# 9176                             Powai, Mumbai
# 63233                      Kondapur, Hyderabad
# 10895  kandivali west charkop sector 5, Mumbai
# 39429                    Mansa Ram Park, Delhi
# 23005                 Domlur Layout, Bangalore
# 55081                      Nizampet, Hyderabad
# 52426                       Sector 24, Gurgaon
# 59593                      Kondapur, Hyderabad
# 42017                        Model Town, Delhi
# 20652                            Dhanori, Pune
# 55088                  Nanakramguda, Hyderabad
# 51763                      Sector 36A, Gurgaon
#
#                               Apartment Name          Status
# 21791                            Marvel Arco       Furnished
# 16124             Pharande Puneville Phase I  Semi-Furnished
# 42312                                    NaN  Semi-Furnished
# 29700                                    NaN       Furnished
# 48807                                    NaN  Semi-Furnished
# 10505                       City Century One     Unfurnished
# 302                  Arihant Anaika Phase II     Unfurnished
# 4649                                     NaN  Semi-Furnished
# 8857   Reputed Builder Vijay Laxmi Residency     Unfurnished
# 24976                                    NaN       Furnished
# 13835                                    NaN  Semi-Furnished
# 26720                                    NaN       Furnished
# 55611                                    NaN  Semi-Furnished
# 41584                                    NaN       Furnished
# 28884                                    NaN       Furnished
# 20454                 Raojee Palladium Homes     Unfurnished
# 42402                                    NaN  Semi-Furnished
# 63442                                    NaN     Unfurnished
# 22757                     Jayshree Boulevard     Unfurnished
# 40353                                    NaN  Semi-Furnished
# 8064                                     NaN     Unfurnished
# 19223                                    NaN  Semi-Furnished
# 28942                                    NaN  Semi-Furnished
# 41091                  DDA Flats Vasant Kunj     Unfurnished
# 25903                                    NaN  Semi-Furnished
# 8588                               Sky Crest     Unfurnished
# 53335                                    NaN  Semi-Furnished
# 27131                                    NaN  Semi-Furnished
# 49758                                    NaN       Furnished
# 52196                                    NaN       Furnished
# 56297                           GM Residency  Semi-Furnished
# 47886              DDA DDA Sector B Pocket 9  Semi-Furnished
# 65255            Reputed Builder Avishikta 2  Semi-Furnished
# 17198                                    NaN  Semi-Furnished
# 4804                 Royal Palms Golden Isle       Furnished
# 30427                                    NaN  Semi-Furnished
# 37145                     DDA Flat Janakpuri  Semi-Furnished
# 534                     Lodha Amara Tower 46     Unfurnished
# 9176                    L And T Emerald Isle  Semi-Furnished
# 63233                                    NaN  Semi-Furnished
# 10895                                    NaN  Semi-Furnished
# 39429                                    NaN  Semi-Furnished
# 23005                                    NaN  Semi-Furnished
# 55081                                    NaN     Unfurnished
# 52426                    DLF Belvedere Tower  Semi-Furnished
# 59593                                    NaN  Semi-Furnished
# 42017                                    NaN       Furnished
# 20652         Goel Ganga Ganga Newtown Ph 02  Semi-Furnished
# 55088                     Pacifica Hillcrest     Unfurnished
# 51763                                 AVL 36       Furnished

# %%
## remove bathrooms from no_of bathroom:
def extract_first_number(x):
    if isinstance(x, str):
        # Split the string and convert the first part to float
        return float(x.split(' ')[0])
    elif isinstance(x, float):
        # If it's already a float, return it as is
        return x
    else:
        # Handle other cases (if any) or return NaN
        return float('nan')

city['Bathrooms'] = city['Bathrooms'].apply(extract_first_number)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  int64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  int64
#  5   Bathrooms           66972 non-null  float64
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 5.1+ MB

# %%
### spliting the adaress into the locality and city

# %%
city['City']=city['Address'].str.split(',').apply(lambda x:x[1])

# %%
city['locality']=city['Address'].str.split(',').apply(lambda x:x[0])

# %%
city.drop(columns=['Address'],inplace=True)

# %%
city.sample(15)
# Out:
#                   broker_consultancy   Rent  Builtup Area  appartment_type  \
# 28261         Seller\nVERIFIED OWNER  65000          1650                3
# 43136         Seller\nVERIFIED OWNER   8500           500                2
# 35              Desire Key\nAGENT\n-  23000           317                1
# 61446  Datrika Enterprises\nAGENT\n0  56000          1885                3
# 17416         Seller\nVERIFIED OWNER   7500           500                1
# 58936         Seller\nVERIFIED OWNER   9000           600                3
# 35786     World Wide Infra\nAGENT\n0  90000          2800                4
# 63680         Seller\nVERIFIED OWNER  30000          1800                3
# 45841         Seller\nVERIFIED OWNER  35000          1200                3
# 66604         Mondal Homes\nAGENT\n0  40000          2200                4
# 6686       Acme Properties\nAGENT\n-  15000           980                2
# 63554          Vikas Kumar\nAGENT\n0  44000          2750                3
# 63831         Samim Baidya\nAGENT\n0  35000          1250                2
# 56844     Individual Agent\nAGENT\n-  25000          1350                2
# 61707        Investors Hub\nAGENT\n-  95000          3070                4
#
#        Deposit  Bathrooms            Facing             Apartment Name  \
# 28261        0        3.0               NaN              Ahad Euphoria
# 43136        0        1.0  NorthWest facing                        NaN
# 35           0        2.0  NorthEast facing                        NaN
# 61446        0        3.0               NaN         Pacifica Hillcrest
# 17416        0        1.0      North facing                        NaN
# 58936        0        1.0               NaN                 The Premia
# 35786        0        4.0               NaN  DDA DDA Sector B Pocket 9
# 63680        0        3.0               NaN                        NaN
# 45841        0        2.0               NaN                        NaN
# 66604        0        4.0               NaN     Sanjeeva Sanjeeva Town
# 6686         0        3.0       East facing              Atlantic Orra
# 63554        0        3.0      North facing                        NaN
# 63831        0        2.0      North facing                        NaN
# 56844        0        2.0               NaN                        NaN
# 61707        0        4.0       East facing          Aparna Luxor Park
#
#                Status        City                             locality
# 28261  Semi-Furnished              Sarjapur Road Post Railway Crossing
# 43136  Semi-Furnished       Delhi                          Uttam Nagar
# 35          Furnished      Mumbai                           Thane West
# 61446  Semi-Furnished   Hyderabad                         Nanakramguda
# 17416  Semi-Furnished        Pune                             Lohegaon
# 58936       Furnished   Hyderabad                              Attapur
# 35786  Semi-Furnished       Delhi                          Vasant Kunj
# 63680       Furnished     Kolkata                            Mourigram
# 45841       Furnished       Delhi                       Swasthya Vihar
# 66604  Semi-Furnished     Kolkata                             New Town
# 6686        Furnished      Mumbai                          Kalyan West
# 63554  Semi-Furnished     Kolkata                            Sector 22
# 63831  Semi-Furnished     Kolkata                       Salt Lake City
# 56844  Semi-Furnished   Hyderabad               Nallagandla Gachibowli
# 61707  Semi-Furnished   Hyderabad                             Kondapur

# %%
city.isna().sum()
# Out:
# broker_consultancy        1
# Rent                      0
# Builtup Area              0
# appartment_type           0
# Deposit                   0
# Bathrooms               344
# Facing                43496
# Apartment Name        40028
# Status                    0
# City                      0
# locality                  0
# dtype: int64

# %%
### feature facing and Appartement name contains losts of na value thats why we are dropping this features from data set

# %%
city.drop(columns=['broker_consultancy','Facing','Apartment Name'],inplace=True)

# %%
### drop null values from the no of bathroom columns

# %%
city.dropna(subset=['Bathrooms'],inplace=True)

# %%
## check for na values

# %%
city.isna().sum()
# Out:
# Rent               0
# Builtup Area       0
# appartment_type    0
# Deposit            0
# Bathrooms          0
# Status             0
# City               0
# locality           0
# dtype: int64

# %%
### check for mathematical information about each numeric feature

# %%
city.describe()
# Out:
#                Rent  Builtup Area  appartment_type       Deposit     Bathrooms
# count  6.697200e+04  66972.000000     66972.000000  6.697200e+04  66972.000000
# mean   4.353986e+04   1250.338858         2.235516  2.127868e+04      2.149376
# std    5.832885e+04    833.393421         0.963631  1.191397e+05      0.980280
# min    1.600000e+03    150.000000         1.000000  0.000000e+00      1.000000
# 25%    1.500000e+04    750.000000         1.000000  0.000000e+00      1.000000
# 50%    2.700000e+04   1060.000000         2.000000  0.000000e+00      2.000000
# 75%    4.800000e+04   1500.000000         3.000000  0.000000e+00      3.000000
# max    1.800000e+06  10000.000000         9.000000  7.200000e+06      8.000000

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66972 entries, 0 to 67315
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rent             66972 non-null  int64
#  1   Builtup Area     66972 non-null  int64
#  2   appartment_type  66972 non-null  int64
#  3   Deposit          66972 non-null  int64
#  4   Bathrooms        66972 non-null  float64
#  5   Status           66972 non-null  object
#  6   City             66972 non-null  object
#  7   locality         66972 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 4.6+ MB

# %%
city['locality'].value_counts()
# Out:
# locality
# Kondapur          3038
# Janakpuri         1490
# Vasant Kunj       1490
# Thane West        1428
# Nanakramguda      1302
#                   ...
# Eksar Rd             1
# Sher e Punjab        1
# 7 Bunglow            1
# Ashok nagar          1
# Gokuldham Marg       1
# Name: count, Length: 463, dtype: int64

# %%
city['locality'].value_counts()

# %%
### converting Qulatative  data into Quantative Type

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
city['City']=encoder.fit_transform(city['City'])

# %%
city['Status']=encoder.fit_transform(city['Status'])

# %%
city['locality']=encoder.fit_transform(city['locality'])

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66972 entries, 0 to 67315
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rent             66972 non-null  int64
#  1   Builtup Area     66972 non-null  int64
#  2   appartment_type  66972 non-null  int64
#  3   Deposit          66972 non-null  int64
#  4   Bathrooms        66972 non-null  float64
#  5   Status           66972 non-null  int64
#  6   City             66972 non-null  int64
#  7   locality         66972 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 4.6 MB

# %%
city['City'].value_counts()
# Out:
# City
# 7    15630
# 3    14900
# 5     8680
# 1     8246
# 8     7220
# 4     5757
# 6     3960
# 2     2140
# 0      438
# 9        1
# Name: count, dtype: int64

# %%
city.describe()
# Out:
#                Rent  Builtup Area  appartment_type       Deposit  \
# count  6.697200e+04  66972.000000     66972.000000  6.697200e+04
# mean   4.353986e+04   1250.338858         2.235516  2.127868e+04
# std    5.832885e+04    833.393421         0.963631  1.191397e+05
# min    1.600000e+03    150.000000         1.000000  0.000000e+00
# 25%    1.500000e+04    750.000000         1.000000  0.000000e+00
# 50%    2.700000e+04   1060.000000         2.000000  0.000000e+00
# 75%    4.800000e+04   1500.000000         3.000000  0.000000e+00
# max    1.800000e+06  10000.000000         9.000000  7.200000e+06
#
#           Bathrooms        Status          City      locality
# count  66972.000000  66972.000000  66972.000000  66972.000000
# mean       2.149376      0.900511      4.697381    231.037239
# std        0.980280      0.654337      2.295351    117.617157
# min        1.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      3.000000    138.000000
# 50%        2.000000      1.000000      5.000000    223.000000
# 75%        3.000000      1.000000      7.000000    316.000000
# max        8.000000      2.000000      9.000000    462.000000

# %%
city.corr()
# Out:
#                      Rent  Builtup Area  appartment_type   Deposit  Bathrooms  \
# Rent             1.000000      0.635984         0.455161  0.497276   0.545752
# Builtup Area     0.635984      1.000000         0.753038  0.231307   0.822911
# appartment_type  0.455161      0.753038         1.000000  0.108366   0.834914
# Deposit          0.497276      0.231307         0.108366  1.000000   0.214753
# Bathrooms        0.545752      0.822911         0.834914  0.214753   1.000000
# Status          -0.018781      0.073686         0.042774  0.023602   0.114376
# City             0.093741      0.013486         0.030825  0.030717   0.073909
# locality         0.016157      0.166369         0.119884  0.041378   0.153295
#
#                    Status      City  locality
# Rent            -0.018781  0.093741  0.016157
# Builtup Area     0.073686  0.013486  0.166369
# appartment_type  0.042774  0.030825  0.119884
# Deposit          0.023602  0.030717  0.041378
# Bathrooms        0.114376  0.073909  0.153295
# Status           1.000000  0.209737 -0.061208
# City             0.209737  1.000000 -0.082110
# locality        -0.061208 -0.082110  1.000000

# %%
city['City'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
city['Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Status'>

# %%
city.describe()
# Out:
#                Rent  Builtup Area  appartment_type       Deposit  \
# count  6.697200e+04  66972.000000     66972.000000  6.697200e+04
# mean   4.353986e+04   1250.338858         2.235516  2.127868e+04
# std    5.832885e+04    833.393421         0.963631  1.191397e+05
# min    1.600000e+03    150.000000         1.000000  0.000000e+00
# 25%    1.500000e+04    750.000000         1.000000  0.000000e+00
# 50%    2.700000e+04   1060.000000         2.000000  0.000000e+00
# 75%    4.800000e+04   1500.000000         3.000000  0.000000e+00
# max    1.800000e+06  10000.000000         9.000000  7.200000e+06
#
#           Bathrooms        Status          City      locality
# count  66972.000000  66972.000000  66972.000000  66972.000000
# mean       2.149376      0.900511      4.697381    231.037239
# std        0.980280      0.654337      2.295351    117.617157
# min        1.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      3.000000    138.000000
# 50%        2.000000      1.000000      5.000000    223.000000
# 75%        3.000000      1.000000      7.000000    316.000000
# max        8.000000      2.000000      9.000000    462.000000
