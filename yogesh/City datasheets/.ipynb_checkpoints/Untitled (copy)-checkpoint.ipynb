# %% [markdown]
# ### problem statement:

# %% [markdown]
# ##### import Required library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### load the cvs files

# %%
# mumbai city csv file:
mumbai=pd.read_csv('mumbai.csv')

# %%
# pune city csv file:
pune=pd.read_csv('pune.csv')

# %%
# Banglore city csv file:
Banglore=pd.read_csv('Banglore.csv')

# %%
# Chennai city csv file:
Chennai=pd.read_csv('Chennai.csv')

# %%
# Delhi city csv file:
Delhi=pd.read_csv('Delhi.csv')

# %%
# gurgaoncity csv file:
gurgaon=pd.read_csv('gurgaon.csv')

# %%
# gurgaoncity csv file:
hyderabad=pd.read_csv('hyderabad.csv')

# %%
# kolkata city csv file:
kolkata=pd.read_csv('kolkata.csv')

# %%
### merge alll above city into one dataframe:
city=pd.concat([mumbai,pune,Banglore,Chennai,Delhi,gurgaon,hyderabad,kolkata],ignore_index=True)

# %%
city
# Out:
#                    broker_consultancy    Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20,000          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20,000          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30,000          1700                3
# 3              Seller\nVERIFIED OWNER  28,500           750                2
# 4              Seller\nVERIFIED OWNER  50,000          1400                3
# ...                               ...     ...           ...              ...
# 67311          Samim Baidya\nAGENT\n0  35,000          1250                2
# 67312            Houseindia\nAGENT\n0  10,000          1100                3
# 67313        TGE PROPERTIES\nAGENT\n0   6,500           500                1
# 67314           Vikas Kumar\nAGENT\n0  44,000          2750                3
# 67315          Sagar Realty\nAGENT\n0  30,000          1100                3
#
#           Deposit    Bathrooms            Facing                  Address  \
# 0      No Deposit  2 bathrooms  NorthEast facing             Ulwe, Mumbai
# 1      No Deposit  2 bathrooms  NorthEast facing             Ulwe, Mumbai
# 2      No Deposit  3 bathrooms  NorthEast facing             Ulwe, Mumbai
# 3      No Deposit  2 bathrooms               NaN   Kandivali West, Mumbai
# 4      No Deposit  3 bathrooms       East facing          Chembur, Mumbai
# ...           ...          ...               ...                      ...
# 67311  No Deposit  2 bathrooms      North facing  Salt Lake City, Kolkata
# 67312  No Deposit  2 bathrooms      South facing         Kalyani, Kolkata
# 67313  No Deposit  1 bathrooms               NaN      Baghajatin, Kolkata
# 67314  No Deposit  3 bathrooms      North facing       Sector 22, Kolkata
# 67315  No Deposit  2 bathrooms  SouthEast facing           Haltu, Kolkata
#
#                     Apartment Name          Status
# 0                        EV Castle     Unfurnished
# 1                              NaN     Unfurnished
# 2                              NaN  Semi-Furnished
# 3                   Atul Blue Arch     Unfurnished
# 4                     Godrej Prime  Semi-Furnished
# ...                            ...             ...
# 67311                          NaN  Semi-Furnished
# 67312                          NaN     Unfurnished
# 67313                          NaN     Unfurnished
# 67314                          NaN  Semi-Furnished
# 67315  Reputed Builder Avishikta 2  Semi-Furnished
#
# [67316 rows x 10 columns]

# %% [markdown]
# ## Data Preprossing

# %%
## taking random sample from dataset:
city.sample(50)
# Out:
#                          broker_consultancy    Rent  Builtup Area  \
# 33604       Furnished
# 64644  Semi-Furnished
# 1341      Unfurnished
# 41504       Furnished
# 13130       Furnished
# 52277       Furnished
# 43427  Semi-Furnished
# 17378  Semi-Furnished
# 55350  Semi-Furnished
# 48371     Unfurnished
# 38712  Semi-Furnished

# %%
### In rent column data contain alphanumeric values like 1.5L,3.5L values we need to convert this into the numeric value

# %%
## conversion of rentcolumn into numeri type:
def convert_rent(rent):
    if "L" in rent:
        return float(rent.replace('L','').replace(',','').strip())*100000                                           
    else:
        return float(rent.replace(',','').strip())

# %%
city['Rent']=city['Rent'].apply(convert_rent)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  float64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
## conversion of Deposit column into the numeric type:
def convert_deposit(deposit):
    if deposit == "No Deposit":
        return 0
    elif isinstance(deposit, str) and 'L' in deposit:
        # Split on 'L', take the first part, convert to float, and multiply by 100000
        return float(deposit.split('L')[0]) * 100000
    else:
        # Handle other cases as needed
        return deposit

city['Deposit'] = city['Deposit'].apply(convert_deposit)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  float64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  object
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
city(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 city(50)
#
# TypeError: 'DataFrame' object is not callable

# %%
city.sample(50)
# Out:
#                              broker_consultancy      Rent  Builtup Area  \
# 29447                    Seller\nVERIFIED OWNER   15000.0          1100
# 52088                    Seller\nVERIFIED OWNER   22000.0          1200
# 22082                    Seller\nVERIFIED OWNER   15500.0           975
# 35710                   Residence Hub\nAGENT\n0   45000.0          1500
# 3128               Home Shopping Mall\nAGENT\n-   24000.0           510
# 10962          Sai Housing Properties\nAGENT\n-   17000.0           660
# 31649                     GB Property\nAGENT\n-   10000.0           720
# 42753                    Access India\nAGENT\n0  275000.0          3200
# 36285          Mahadev Renting Expert\nAGENT\n-   32500.0          1100
# 5502               Sunrise Properties\nAGENT\n-   43000.0           575
# 45558                    Seller\nVERIFIED OWNER   20000.0           810
# 41581                    Seller\nVERIFIED OWNER   35000.0          1200
# 3001                 Aryan Properties\nAGENT\n-   60000.0          1500
# 58645                          Ishaan\nAGENT\n-   50000.0          2050
# 36472               CK Home Solutions\nAGENT\n0   15000.0           850
# 43925          Mahadev Renting Expert\nAGENT\n0   32500.0          1100
# 25104                    Seller\nVERIFIED OWNER    8000.0           300
# 62416                    Seller\nVERIFIED OWNER    9000.0           600
# 3068   Shree Swami Samarth Properties\nAGENT\n-   69000.0          1000
# 31262                    Seller\nVERIFIED OWNER   18000.0          1000
# 23502                    Seller\nVERIFIED OWNER   18000.0          1000
# 32022                    Seller\nVERIFIED OWNER   15000.0           836
# 59242                    Seller\nVERIFIED OWNER   20000.0          1800
# 31071                    Seller\nVERIFIED OWNER   14000.0           450
# 30281                    Seller\nVERIFIED OWNER   65000.0          1650
# 49968                    Seller\nVERIFIED OWNER   22000.0          1200
# 64246             Abhijit Chakraborty\nAGENT\n0  125000.0          3000
# 60145                          Ishaan\nAGENT\n0   50000.0          2050
# 13913            Bhadrakaliproperties\nAGENT\n-  100000.0          1000
# 16687                MY HOMES GATEWAY\nAGENT\n0   36000.0          1560
# 43925                               DDA Flat Janakpuri  Semi-Furnished
# 25104                                              NaN       Furnished
# 62416                                       The Premia       Furnished
# 3068                                               NaN       Furnished
# 31262                                              NaN  Semi-Furnished
# 23502                                              NaN  Semi-Furnished
# 32022                                    Mahindra Nova  Semi-Furnished
# 59242                                              NaN       Furnished
# 31071                                              NaN  Semi-Furnished
# 30281                                    Ahad Euphoria  Semi-Furnished
# 49968                                              NaN  Semi-Furnished
# 64246                                              NaN       Furnished
# 60145                                              NaN  Semi-Furnished
# 13913                           Suyash Shopping Centre     Unfurnished
# 16687                                Karan Madhupushpa  Semi-Furnished
# 2099                             Royal Palms Ruby Isle       Furnished
# 15160                        Lodha Palava Paseo D To H     Unfurnished
# 36609                                              NaN  Semi-Furnished
# 39087                                              NaN  Semi-Furnished
# 65074                                              NaN  Semi-Furnished
# 18715  Paranjape Blue Ridge Project E Land T24 And T25  Semi-Furnished
# 41990                                              NaN       Furnished
# 39396                                              NaN  Semi-Furnished
# 29399                                              NaN       Furnished
# 17658                                              NaN  Semi-Furnished
# 25863                                              NaN  Semi-Furnished
# 6339     Reliance Tilak Nagar Nisarg Co Op Hsg Soc Ltd     Unfurnished
# 45774                                              NaN  Semi-Furnished
# 36368                                              NaN  Semi-Furnished
# 35857                                              NaN       Furnished
# 24510                                              NaN  Semi-Furnished
# 20738                                              NaN  Semi-Furnished
# 11921                                              NaN  Semi-Furnished
# 44253                                              NaN  Semi-Furnished
# 22246                     Tirupati Welworth Bluescapes  Semi-Furnished

# %%
## remove bathrooms from no_of bathroom:
def extract_first_number(x):
    if isinstance(x, str):
        # Split the string and convert the first part to float
        return float(x.split(' ')[0])
    elif isinstance(x, float):
        # If it's already a float, return it as is
        return x
    else:
        # Handle other cases (if any) or return NaN
        return float('nan')

city['Bathrooms'] = city['Bathrooms'].apply(extract_first_number)

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67316 entries, 0 to 67315
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  67315 non-null  object
#  1   Rent                67316 non-null  float64
#  2   Builtup Area        67316 non-null  int64
#  3   appartment_type     67316 non-null  int64
#  4   Deposit             67316 non-null  object
#  5   Bathrooms           66972 non-null  float64
#  6   Facing              23820 non-null  object
#  7   Address             67316 non-null  object
#  8   Apartment Name      27288 non-null  object
#  9   Status              67316 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 5.1+ MB

# %%
### spliting the adaress into the locality and city

# %%
city['City']=city['Address'].str.split(',').apply(lambda x:x[1])

# %%
city
# Out:
#                    broker_consultancy     Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20000.0          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20000.0          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30000.0          1700                3
# 3              Seller\nVERIFIED OWNER  28500.0           750                2
# 4              Seller\nVERIFIED OWNER  50000.0          1400                3
# ...                               ...      ...           ...              ...
# 67311          Samim Baidya\nAGENT\n0  35000.0          1250                2
# 67312            Houseindia\nAGENT\n0  10000.0          1100                3
# 67313        TGE PROPERTIES\nAGENT\n0   6500.0           500                1
# 67314           Vikas Kumar\nAGENT\n0  44000.0          2750                3
# 67315          Sagar Realty\nAGENT\n0  30000.0          1100                3
#
#       Deposit  Bathrooms            Facing                  Address  \
# 0           0        2.0  NorthEast facing             Ulwe, Mumbai
# 1           0        2.0  NorthEast facing             Ulwe, Mumbai
# 2           0        3.0  NorthEast facing             Ulwe, Mumbai
# 3           0        2.0               NaN   Kandivali West, Mumbai
# 4           0        3.0       East facing          Chembur, Mumbai
# ...       ...        ...               ...                      ...
# 67311       0        2.0      North facing  Salt Lake City, Kolkata
# 67312       0        2.0      South facing         Kalyani, Kolkata
# 67313       0        1.0               NaN      Baghajatin, Kolkata
# 67314       0        3.0      North facing       Sector 22, Kolkata
# 67315       0        2.0  SouthEast facing           Haltu, Kolkata
#
#                     Apartment Name          Status      City
# 0                        EV Castle     Unfurnished    Mumbai
# 1                              NaN     Unfurnished    Mumbai
# 2                              NaN  Semi-Furnished    Mumbai
# 3                   Atul Blue Arch     Unfurnished    Mumbai
# 4                     Godrej Prime  Semi-Furnished    Mumbai
# ...                            ...             ...       ...
# 67311                          NaN  Semi-Furnished   Kolkata
# 67312                          NaN     Unfurnished   Kolkata
# 67313                          NaN     Unfurnished   Kolkata
# 67314                          NaN  Semi-Furnished   Kolkata
# 67315  Reputed Builder Avishikta 2  Semi-Furnished   Kolkata
#
# [67316 rows x 11 columns]

# %%
city['locality']=city['Address'].str.split(',').apply(lambda x:x[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Address'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 city['locality']=city['Address'].str.split(',').apply(lambda x:x[0])
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Address'

# %%
city.drop(columns=['Address'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 city.drop(columns=['Address'],inplace=True)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Address'] not found in axis"

# %%
city
# Out:
#                    broker_consultancy     Rent  Builtup Area  appartment_type  \
# 0      Kasturi Developers\nBUILDER\n-  20000.0          1132                2
# 1      Kasturi Developers\nBUILDER\n-  20000.0          1200                2
# 2      Kasturi Developers\nBUILDER\n-  30000.0          1700                3
# 3              Seller\nVERIFIED OWNER  28500.0           750                2
# 4              Seller\nVERIFIED OWNER  50000.0          1400                3
# ...                               ...      ...           ...              ...
# 67311          Samim Baidya\nAGENT\n0  35000.0          1250                2
# 67312            Houseindia\nAGENT\n0  10000.0          1100                3
# 67313        TGE PROPERTIES\nAGENT\n0   6500.0           500                1
# 67314           Vikas Kumar\nAGENT\n0  44000.0          2750                3
# 67315          Sagar Realty\nAGENT\n0  30000.0          1100                3
#
#       Deposit  Bathrooms            Facing               Apartment Name  \
# 0           0        2.0  NorthEast facing                    EV Castle
# 1           0        2.0  NorthEast facing                          NaN
# 2           0        3.0  NorthEast facing                          NaN
# 3           0        2.0               NaN               Atul Blue Arch
# 4           0        3.0       East facing                 Godrej Prime
# ...       ...        ...               ...                          ...
# 67311       0        2.0      North facing                          NaN
# 67312       0        2.0      South facing                          NaN
# 67313       0        1.0               NaN                          NaN
# 67314       0        3.0      North facing                          NaN
# 67315       0        2.0  SouthEast facing  Reputed Builder Avishikta 2
#
#                Status      City        locality
# 0         Unfurnished    Mumbai            Ulwe
# 1         Unfurnished    Mumbai            Ulwe
# 2      Semi-Furnished    Mumbai            Ulwe
# 3         Unfurnished    Mumbai  Kandivali West
# 4      Semi-Furnished    Mumbai         Chembur
# ...               ...       ...             ...
# 67311  Semi-Furnished   Kolkata  Salt Lake City
# 67312     Unfurnished   Kolkata         Kalyani
# 67313     Unfurnished   Kolkata      Baghajatin
# 67314  Semi-Furnished   Kolkata       Sector 22
# 67315  Semi-Furnished   Kolkata           Haltu
#
# [67316 rows x 11 columns]

# %%
city.sample(15)
# Out:
#                       broker_consultancy      Rent  Builtup Area  \
# 8818          Shree Associates\nAGENT\n-   14000.0           650
# 2189         Brahma Sai Realty\nAGENT\n-   75000.0           930
# 10411             Sai Property\nAGENT\n-   24000.0           685
# 616                   Raj Alma\nAGENT\n-   27000.0           595
# 59903                     Asif\nAGENT\n0  115000.0          3130
# 52789             Seller\nVERIFIED OWNER   13000.0          1000
# 2719                   Parvati\nAGENT\n-   20000.0           530
# 14649               Roshan Dcunha\nOWNER   22000.0           900
# 54881             Seller\nVERIFIED OWNER   30000.0          2400
# 6334     Quick Home Properties\nAGENT\n-  160000.0          2100
# 34963          Neon Properties\nAGENT\n0   65000.0          1500
# 62258             Seller\nVERIFIED OWNER   45000.0          3000
# 1842   Ramachandra Real Estate\nAGENT\n-  250000.0          1400
# 45470            Residence Hub\nAGENT\n-   45000.0          1500
# 16691      Melange Consultancy\nAGENT\n-   48000.0          1300
#
#        appartment_type   Deposit  Bathrooms            Facing  \
# 8818                 1         0        1.0       West facing
# 2189                 2         0        2.0       West facing
# 10411                1  100000.0        2.0               NaN
# 616                  1         0        1.0               NaN
# 59903                3         0        3.0               NaN
# 52789                1         0        1.0               NaN
# 2719                 1         0        2.0               NaN
# 14649                2         0        2.0       East facing
# 54881                4         0        4.0               NaN
# 6334                 4         0        3.0  NorthWest facing
# 34963                2         0        2.0  NorthEast facing
# 62258                4         0        4.0       West facing
# 1842                 2         0        2.0       West facing
# 45470                3         0        3.0               NaN
# 16691                2         0        2.0               NaN
#
#                          Apartment Name          Status        City  \
# 8818        Reputed Builder Arti Nagari     Unfurnished      Mumbai
# 2189                      Ekta Tripolis  Semi-Furnished      Mumbai
# 10411                        On Request  Semi-Furnished      Mumbai
# 616                                Park     Unfurnished      Mumbai
# 59903                    Dream Valencia  Semi-Furnished   Hyderabad
# 52789           HUDA RWA Swaran Jayanti  Semi-Furnished     Gurgaon
# 2719                       Vijay Orovia  Semi-Furnished      Mumbai
# 14649                               NaN  Semi-Furnished      Mumbai
# 54881                               NaN     Unfurnished   Hyderabad
# 6334                         Godrej RKS       Furnished      Mumbai
# 34963                               NaN  Semi-Furnished       Delhi
# 62258                               NaN       Furnished   Hyderabad
# 1842   Enpar Lotus 101 Worli Residences  Semi-Furnished      Mumbai
# 45470                               NaN       Furnished       Delhi
# 16691                       Marvel Arco       Furnished        Pune
#
#                        locality
# 8818                Kalyan West
# 2189              Goregaon West
# 10411                  Seawoods
# 616              Kandivali East
# 59903             Banjara Hills
# 52789                  Sector 4
# 2719                 Thane West
# 14649                  Seawoods
# 54881                  Nizampet
# 6334                    Chembur
# 34963                Neeti Bagh
# 62258                Shamshabad
# 1842                      Worli
# 45470  Freedom Fighters Enclave
# 16691                  Hadapsar

# %%
city['City'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
city['Status'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Status'>

# %%
city['Facing'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Facing'>

# %%
city.describe()
