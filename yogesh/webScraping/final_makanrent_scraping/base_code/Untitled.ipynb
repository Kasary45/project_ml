# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('mumbai.csv')

# %%
df
# Out:
#                          broker_consultancy    Rent  Builtup Area  \
# 0            Kasturi Developers\nBUILDER\n-  20,000          1132
# 1            Kasturi Developers\nBUILDER\n-  20,000          1200
# 2            Kasturi Developers\nBUILDER\n-  30,000          1700
# 3                    Seller\nVERIFIED OWNER  28,500           750
# 4                    Seller\nVERIFIED OWNER  50,000          1400
# ...                                     ...     ...           ...
# 15671  Amresh Property Ghansoli\nBUILDER\n-  16,000           650
# 15672  Amresh Property Ghansoli\nBUILDER\n-  39,000           687
# 15673  Amresh Property Ghansoli\nBUILDER\n-  18,000           680
# 15674  Amresh Property Ghansoli\nBUILDER\n-  33,500          1250
# 15675  Amresh Property Ghansoli\nBUILDER\n-  35,000          1200
#
#        appartment_type         Deposit    Bathrooms            Facing  \
# 0                    2      No Deposit  2 bathrooms  NorthEast facing
# ...

# %%
df.isna().sum()
# Out:
# broker_consultancy       1
# Rent                     0
# Builtup Area             0
# appartment_type          0
# Deposit                  0
# Bathrooms               41
# Facing                8434
# Address                  0
# Apartment Name        4386
# Status                   0
# dtype: int64

# %%
df.describe()
# Out:
#        Builtup Area  appartment_type
# count  15676.000000     15676.000000
# mean    1001.378221         1.918921
# std      569.585788         0.848902
# min      150.000000         1.000000
# 25%      650.000000         1.000000
# 50%      900.000000         2.000000
# 75%     1200.000000         2.000000
# max     8500.000000         9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15676 entries, 0 to 15675
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   broker_consultancy  15675 non-null  object
#  1   Rent                15676 non-null  object
#  2   Builtup Area        15676 non-null  int64
#  3   appartment_type     15676 non-null  int64
#  4   Deposit             15676 non-null  object
#  5   Bathrooms           15635 non-null  object
#  6   Facing              7242 non-null   object
#  7   Address             15676 non-null  object
#  8   Apartment Name      11290 non-null  object
#  9   Status              15676 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 1.2+ MB

# %%
# convert the status  to numeric values
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['Status'] = encoder.fit_transform(df['Status'])

# %%
df['Status']
# Out:
# 0        2
# 1        2
# 2        1
# 3        2
# 4        1
#         ..
# 15671    2
# 15672    0
# 15673    2
# 15674    0
# 15675    0
# Name: Status, Length: 15676, dtype: int64

# %%
df.describe()
# Out:
#        Builtup Area  appartment_type        Status
# count  15676.000000     15676.000000  15676.000000
# mean    1001.378221         1.918921      1.088734
# std      569.585788         0.848902      0.754596
# min      150.000000         1.000000      0.000000
# 25%      650.000000         1.000000      1.000000
# 50%      900.000000         2.000000      1.000000
# 75%     1200.000000         2.000000      2.000000
# max     8500.000000         9.000000      2.000000

# %%
# convert the status  to numeric values
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['appartment_type'] = encoder.fit_transform(df['appartment_type'])

# %%
df.describe()
# Out:
#        Builtup Area  appartment_type        Status
# count  15676.000000     15676.000000  15676.000000
# mean    1001.378221         0.918921      1.088734
# std      569.585788         0.848902      0.754596
# min      150.000000         0.000000      0.000000
# 25%      650.000000         0.000000      1.000000
# 50%      900.000000         1.000000      1.000000
# 75%     1200.000000         1.000000      2.000000
# max     8500.000000         8.000000      2.000000

# %%
# convert the status  to numeric values
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['Address'] = encoder.fit_transform(df['Address'])

# %%
df.describe()
# Out:
#        Builtup Area  appartment_type       Address        Status
# count  15676.000000     15676.000000  15676.000000  15676.000000
# mean    1001.378221         0.918921    147.568002      1.088734
# std      569.585788         0.848902     91.121213      0.754596
# min      150.000000         0.000000      0.000000      0.000000
# 25%      650.000000         0.000000     78.000000      1.000000
# 50%      900.000000         1.000000    137.000000      1.000000
# 75%     1200.000000         1.000000    209.000000      2.000000
# max     8500.000000         8.000000    353.000000      2.000000

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.corr()
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# converting all columns to string ty
df['Rent'].astype(int)
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # converting all columns to string ty
# ----> 2 df['Rent'].astype(int)
#       3 df.info()
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...
